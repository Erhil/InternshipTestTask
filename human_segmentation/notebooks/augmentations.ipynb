# %%
import os
os.chdir("..")
print(os.getcwd())

import warnings
warnings.filterwarnings("ignore")

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

from tqdm import tqdm

import torch
from torch import nn
from torch import optim
from torch import autograd as ag

from torch.utils.data import DataLoader, Dataset

import segmentation_models_pytorch as smp

# %matplotlib inline

import time

# %%
import imgaug as ia
import imgaug.augmenters as iaa

# %%
# paths to data
TRAIN = os.path.join("data", "train")
TRAIN_MSK = os.path.join("data", "train_mask")
VAL= os.path.join("data", "valid")
VAL_MSK = os.path.join("data", "valid_mask")

# %%
class SegmentationData(Dataset):
    """
    Dataset class
    
    :img_path: path to images
    :mask_path: path to masks
    
    """
    
    def __init__(self, img_path, mask_path, size=(224, 224), preprocessing=None, augmentation=None):
        ids = [x.split(".")[0] for x in os.listdir(img_path)]
        self.img_paths = [os.path.join(img_path, x+".jpg") for x in ids]
        self.mask_paths = [os.path.join(mask_path, x+".png") for x in ids]
        self.size = size
        
        
        self.preprocessing = preprocessing
        self.augmentation = augmentation
        
    def __getitem__(self, i):
        # load data
        img = plt.imread(self.img_paths[i])
        img = cv2.resize(img, self.size)
        
        mask = plt.imread(self.mask_paths[i])
        mask = cv2.resize(mask, self.size)
        
        img = img.astype(np.float32)/255
        mask = mask[np.newaxis, :, :, ]
        mask = mask.astype(np.uint8)
        
        # apply preprocessing if needed
        if self.preprocessing:
            img, mask = self.preprocessing(image=img, mask=mask)
    
        # apply augmentation if needed
        if self.augmentation:
            img, mask = self.augmentation(image=img, segmentation_maps=mask)
          
        img = np.rollaxis(img, 2, 0)
        
        return (torch.from_numpy(img.copy()), torch.from_numpy(mask.astype(np.float32)))
            
    def __len__(self):
        return len(self.img_paths)

# %%
aug = iaa.Sequential([
    iaa.Fliplr(0.5),
    iaa.Flipud(0.05),
    
    iaa.Sometimes(
        0.5, 
        iaa.Crop(px=(0, 20))
    ),
    
    iaa.SomeOf(
        (0,3),
        [
            iaa.GaussianBlur(sigma=(0, 2)),
             iaa.GammaContrast(per_channel=True, gamma=(0.25,1.75)),
             iaa.LinearContrast(alpha=(0.25,1.75), per_channel=True)
        ]
    ),
    
    iaa.Sometimes(
        0.8,
        [iaa.Sometimes(
                0.3,
                iaa.OneOf([
                    iaa.ElasticTransformation(alpha=20, sigma=1),
                    iaa.ElasticTransformation(alpha=200, sigma=20)
                ])
        ),


        iaa.Sometimes(0.3, 
            iaa.Affine(
                scale={"x": (0.9, 1.1), "y": (0.8, 1.2)},
                rotate=(-20, 20),
                order=[0, 1]
            )
        )]
    )
])

# %%
train_data = SegmentationData(TRAIN, TRAIN_MSK)
val_data = SegmentationData(VAL, VAL_MSK)

train_loader = DataLoader(train_data, batch_size=16, shuffle=True, num_workers=0)
val_loader = DataLoader(val_data, batch_size=1, shuffle=False, num_workers=0)

# %%
BASE_MODEL = "resnet18"
MODEL_WEGHTS = "imagenet"
DEVICE = "cuda:0" if torch.cuda.is_available() else "cpu"

# %%
criterion = smp.utils.losses.BCEDiceLoss()
metrics = [
    smp.utils.metrics.IoUMetric(),
    smp.utils.metrics.FscoreMetric()
]

# %%
model = smp.Unet(BASE_MODEL, MODEL_WEGHTS)

# %%
optimizer = optim.Adam([
    {"params": model.encoder.parameters(), "lr" : 1e-6},
    {"params": model.decoder.parameters(), "lr" : 1e-4},
])

# %%
# create epoch runners 
# it is a simple loop of iterating over dataloader`s samples
train_epoch = smp.utils.train.TrainEpoch(
    model, 
    loss=criterion, 
    metrics=metrics, 
    optimizer=optimizer,
    device=DEVICE,
    verbose=True,
)

val_epoch = smp.utils.train.ValidEpoch(
    model, 
    loss=criterion, 
    metrics=metrics, 
    device=DEVICE,
    verbose=True,
)

# %%
augmentations = {}

# %%
max_score = 0

for i in range(0, 50):
    
    print('\nEpoch: {}'.format(i))
    train_logs = train_epoch.run(train_loader)
    valid_logs = val_epoch.run(val_loader)
    
    # do something (save model, change lr, etc.)
    if max_score < valid_logs['iou']:
        max_score = valid_logs['iou']
        torch.save(model, 'models/best_model_unet_resnet18_noaug.pth')
        augmentations["no_aug"] = {"iou": valid_logs["iou"], 
                           "f-score": valid_logs["f-score"] 
                          }
        print('Model saved!')
            
    if i == 25:
        optimizer.param_groups[1]['lr'] = 1e-5
        optimizer.param_groups[0]['lr'] = 1e-7
# Out:
# Epoch: 0
# train: 100%|███████████████████| 83/83 [00:51<00:00,  1.61it/s, bce_dice_loss - 0.6602, iou - 0.7216, f-score - 0.8313]
# valid: 100%|█████████████████| 100/100 [00:03<00:00, 29.72it/s, bce_dice_loss - 0.3935, iou - 0.8271, f-score - 0.8998]
# Model saved!
#
# Epoch: 1
# train: 100%|████████████████████| 83/83 [00:52<00:00,  1.59it/s, bce_dice_loss - 0.2875, iou - 0.884, f-score - 0.9383]
# valid: 100%|█████████████████| 100/100 [00:03<00:00, 32.99it/s, bce_dice_loss - 0.2872, iou - 0.8719, f-score - 0.9276]
# Model saved!
#
# Epoch: 2
# train: 100%|███████████████████| 83/83 [00:50<00:00,  1.64it/s, bce_dice_loss - 0.2161, iou - 0.9101, f-score - 0.9528]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.29it/s, bce_dice_loss - 0.2541, iou - 0.8869, f-score - 0.9364]
# Model saved!
#
# Epoch: 3
# train: 100%|███████████████████| 83/83 [00:50<00:00,  1.65it/s, bce_dice_loss - 0.1761, iou - 0.9261, f-score - 0.9616]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.05it/s, bce_dice_loss - 0.2368, iou - 0.8934, f-score - 0.9405]
# Model saved!
#
# Epoch: 4
# train: 100%|███████████████████| 83/83 [00:50<00:00,  1.64it/s, bce_dice_loss - 0.1485, iou - 0.9372, f-score - 0.9676]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.24it/s, bce_dice_loss - 0.2298, iou - 0.8995, f-score - 0.9438]
# Model saved!
#
# Epoch: 5
# train: 100%|███████████████████| 83/83 [00:50<00:00,  1.64it/s, bce_dice_loss - 0.1388, iou - 0.9414, f-score - 0.9697]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.52it/s, bce_dice_loss - 0.2064, iou - 0.9066, f-score - 0.9482]
# Model saved!
#
# Epoch: 6
# train: 100%|████████████████████| 83/83 [00:52<00:00,  1.60it/s, bce_dice_loss - 0.1232, iou - 0.9474, f-score - 0.973]
# valid: 100%|█████████████████| 100/100 [00:03<00:00, 27.10it/s, bce_dice_loss - 0.2019, iou - 0.9108, f-score - 0.9504]
# Model saved!
#
# Epoch: 7
# train: 100%|████████████████████| 83/83 [00:52<00:00,  1.58it/s, bce_dice_loss - 0.1126, iou - 0.952, f-score - 0.9754]
# valid: 100%|██████████████████| 100/100 [00:03<00:00, 32.01it/s, bce_dice_loss - 0.1964, iou - 0.9134, f-score - 0.952]
# Model saved!
#
# Epoch: 8
# train: 100%|███████████████████| 83/83 [00:51<00:00,  1.60it/s, bce_dice_loss - 0.1062, iou - 0.9548, f-score - 0.9768]
# valid: 100%|█████████████████| 100/100 [00:03<00:00, 32.14it/s, bce_dice_loss - 0.1964, iou - 0.9154, f-score - 0.9536]
# Model saved!
#
# Epoch: 9
# train: 100%|██████████████████| 83/83 [00:52<00:00,  1.58it/s, bce_dice_loss - 0.09731, iou - 0.9585, f-score - 0.9788]
# valid: 100%|█████████████████| 100/100 [00:03<00:00, 31.40it/s, bce_dice_loss - 0.1998, iou - 0.9152, f-score - 0.9533]
#
# Epoch: 10
# train: 100%|██████████████████| 83/83 [00:52<00:00,  1.59it/s, bce_dice_loss - 0.08848, iou - 0.9621, f-score - 0.9807]
# valid: 100%|█████████████████| 100/100 [00:03<00:00, 31.27it/s, bce_dice_loss - 0.1945, iou - 0.9192, f-score - 0.9555]
# Model saved!
#
# Epoch: 11
# train: 100%|██████████████████| 83/83 [00:53<00:00,  1.56it/s, bce_dice_loss - 0.08509, iou - 0.9633, f-score - 0.9813]
# valid: 100%|█████████████████| 100/100 [00:03<00:00, 31.81it/s, bce_dice_loss - 0.1956, iou - 0.9178, f-score - 0.9549]
#
# Epoch: 12
# train: 100%|██████████████████| 83/83 [00:52<00:00,  1.60it/s, bce_dice_loss - 0.08194, iou - 0.9654, f-score - 0.9824]
# valid: 100%|█████████████████| 100/100 [00:03<00:00, 31.38it/s, bce_dice_loss - 0.1858, iou - 0.9212, f-score - 0.9562]
# Model saved!
#
# Epoch: 13
# train: 100%|███████████████████| 83/83 [00:51<00:00,  1.60it/s, bce_dice_loss - 0.0827, iou - 0.9643, f-score - 0.9818]
# valid: 100%|█████████████████| 100/100 [00:03<00:00, 32.60it/s, bce_dice_loss - 0.1848, iou - 0.9213, f-score - 0.9566]
# Model saved!
#
# Epoch: 14
# train: 100%|██████████████████| 83/83 [00:52<00:00,  1.59it/s, bce_dice_loss - 0.07508, iou - 0.9675, f-score - 0.9834]
# valid: 100%|█████████████████| 100/100 [00:03<00:00, 32.02it/s, bce_dice_loss - 0.1906, iou - 0.9205, f-score - 0.9562]
#
# Epoch: 15
# train: 100%|██████████████████| 83/83 [00:52<00:00,  1.59it/s, bce_dice_loss - 0.07576, iou - 0.9671, f-score - 0.9833]
# valid: 100%|█████████████████| 100/100 [00:03<00:00, 32.33it/s, bce_dice_loss - 0.1887, iou - 0.9217, f-score - 0.9571]
# Model saved!
#
# Epoch: 16
# train: 100%|██████████████████| 83/83 [00:52<00:00,  1.59it/s, bce_dice_loss - 0.07909, iou - 0.9655, f-score - 0.9825]
# valid: 100%|█████████████████| 100/100 [00:03<00:00, 31.83it/s, bce_dice_loss - 0.1964, iou - 0.9191, f-score - 0.9556]
#
# Epoch: 17
# train: 100%|██████████████████| 83/83 [00:52<00:00,  1.59it/s, bce_dice_loss - 0.06763, iou - 0.9709, f-score - 0.9852]
# valid: 100%|██████████████████| 100/100 [00:03<00:00, 32.56it/s, bce_dice_loss - 0.1976, iou - 0.918, f-score - 0.9549]
#
# Epoch: 18
# train: 100%|██████████████████| 83/83 [00:52<00:00,  1.58it/s, bce_dice_loss - 0.06264, iou - 0.9727, f-score - 0.9862]
# valid: 100%|█████████████████| 100/100 [00:03<00:00, 30.52it/s, bce_dice_loss - 0.1923, iou - 0.9233, f-score - 0.9579]
# Model saved!
#
# Epoch: 19
# train: 100%|██████████████████| 83/83 [00:52<00:00,  1.58it/s, bce_dice_loss - 0.06081, iou - 0.9735, f-score - 0.9866]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 33.92it/s, bce_dice_loss - 0.1865, iou - 0.9247, f-score - 0.9588]
# Model saved!
#
# Epoch: 20
# train: 100%|██████████████████| 83/83 [00:51<00:00,  1.60it/s, bce_dice_loss - 0.05952, iou - 0.9742, f-score - 0.9869]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 34.07it/s, bce_dice_loss - 0.1861, iou - 0.9254, f-score - 0.959]
# Model saved!
#
# Epoch: 21
# train: 100%|██████████████████| 83/83 [00:51<00:00,  1.62it/s, bce_dice_loss - 0.06116, iou - 0.9735, f-score - 0.9865]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.12it/s, bce_dice_loss - 0.1968, iou - 0.9212, f-score - 0.9566]
#
# Epoch: 22
# train: 100%|███████████████████| 83/83 [00:51<00:00,  1.61it/s, bce_dice_loss - 0.06158, iou - 0.973, f-score - 0.9863]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 34.19it/s, bce_dice_loss - 0.202, iou - 0.9202, f-score - 0.9556]
#
# Epoch: 23
# train: 100%|██████████████████| 83/83 [00:52<00:00,  1.59it/s, bce_dice_loss - 0.05596, iou - 0.9754, f-score - 0.9876]
# valid: 100%|█████████████████| 100/100 [00:03<00:00, 33.17it/s, bce_dice_loss - 0.1889, iou - 0.9244, f-score - 0.9583]
#
# Epoch: 24
# train: 100%|██████████████████| 83/83 [00:51<00:00,  1.62it/s, bce_dice_loss - 0.05173, iou - 0.9773, f-score - 0.9885]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.57it/s, bce_dice_loss - 0.1976, iou - 0.9207, f-score - 0.9559]
#
# Epoch: 25
# train: 100%|██████████████████| 83/83 [00:50<00:00,  1.65it/s, bce_dice_loss - 0.05095, iou - 0.9776, f-score - 0.9886]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.80it/s, bce_dice_loss - 0.1874, iou - 0.9242, f-score - 0.9586]
#
# Epoch: 26
# train: 100%|██████████████████| 83/83 [00:50<00:00,  1.65it/s, bce_dice_loss - 0.04794, iou - 0.9788, f-score - 0.9893]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.08it/s, bce_dice_loss - 0.1828, iou - 0.9264, f-score - 0.9595]
# Model saved!
#
# Epoch: 27
# train: 100%|██████████████████| 83/83 [00:50<00:00,  1.65it/s, bce_dice_loss - 0.04831, iou - 0.9789, f-score - 0.9893]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.97it/s, bce_dice_loss - 0.1855, iou - 0.9259, f-score - 0.9594]
#
# Epoch: 28
# train: 100%|██████████████████| 83/83 [00:50<00:00,  1.65it/s, bce_dice_loss - 0.04684, iou - 0.9794, f-score - 0.9896]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.91it/s, bce_dice_loss - 0.1875, iou - 0.9255, f-score - 0.9591]
#
# Epoch: 29
# train: 100%|███████████████████| 83/83 [00:50<00:00,  1.64it/s, bce_dice_loss - 0.0473, iou - 0.9793, f-score - 0.9895]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.02it/s, bce_dice_loss - 0.1874, iou - 0.9258, f-score - 0.9594]
#
# Epoch: 30
# train: 100%|████████████████████| 83/83 [00:50<00:00,  1.65it/s, bce_dice_loss - 0.0527, iou - 0.9768, f-score - 0.988]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.31it/s, bce_dice_loss - 0.1939, iou - 0.9251, f-score - 0.9585]
#
# Epoch: 31
# train: 100%|██████████████████| 83/83 [00:50<00:00,  1.65it/s, bce_dice_loss - 0.04748, iou - 0.9791, f-score - 0.9895]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.19it/s, bce_dice_loss - 0.1906, iou - 0.9238, f-score - 0.9582]
#
# Epoch: 32
# train: 100%|██████████████████| 83/83 [00:50<00:00,  1.66it/s, bce_dice_loss - 0.04563, iou - 0.9799, f-score - 0.9898]
# valid: 100%|███████████████████| 100/100 [00:02<00:00, 35.63it/s, bce_dice_loss - 0.188, iou - 0.925, f-score - 0.9587]
#
# Epoch: 33
# train: 100%|██████████████████| 83/83 [00:50<00:00,  1.65it/s, bce_dice_loss - 0.04704, iou - 0.9795, f-score - 0.9896]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.17it/s, bce_dice_loss - 0.1877, iou - 0.9245, f-score - 0.9587]
#
# Epoch: 34
# train: 100%|██████████████████| 83/83 [00:50<00:00,  1.66it/s, bce_dice_loss - 0.04881, iou - 0.9791, f-score - 0.9894]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.21it/s, bce_dice_loss - 0.1899, iou - 0.9246, f-score - 0.9586]
#
# Epoch: 35
# train: 100%|██████████████████| 83/83 [00:50<00:00,  1.65it/s, bce_dice_loss - 0.04587, iou - 0.9798, f-score - 0.9898]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.10it/s, bce_dice_loss - 0.1916, iou - 0.9249, f-score - 0.9586]
#
# Epoch: 36
# train: 100%|██████████████████| 83/83 [00:50<00:00,  1.66it/s, bce_dice_loss - 0.04556, iou - 0.9799, f-score - 0.9898]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.34it/s, bce_dice_loss - 0.1916, iou - 0.9256, f-score - 0.9592]
#
# Epoch: 37
# train: 100%|██████████████████| 83/83 [00:50<00:00,  1.66it/s, bce_dice_loss - 0.04633, iou - 0.9796, f-score - 0.9897]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.96it/s, bce_dice_loss - 0.1916, iou - 0.9253, f-score - 0.9589]
#
# Epoch: 38
# train: 100%|████████████████████| 83/83 [00:50<00:00,  1.65it/s, bce_dice_loss - 0.04508, iou - 0.98, f-score - 0.9899]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.95it/s, bce_dice_loss - 0.1906, iou - 0.9253, f-score - 0.9589]
#
# Epoch: 39
# train: 100%|██████████████████| 83/83 [00:50<00:00,  1.66it/s, bce_dice_loss - 0.04471, iou - 0.9803, f-score - 0.9901]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.11it/s, bce_dice_loss - 0.1912, iou - 0.9251, f-score - 0.9589]
#
# Epoch: 40
# train: 100%|██████████████████| 83/83 [00:50<00:00,  1.66it/s, bce_dice_loss - 0.04621, iou - 0.9797, f-score - 0.9897]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.71it/s, bce_dice_loss - 0.1936, iou - 0.9247, f-score - 0.9583]
#
# Epoch: 41
# train: 100%|██████████████████| 83/83 [00:50<00:00,  1.66it/s, bce_dice_loss - 0.04447, iou - 0.9804, f-score - 0.9901]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 35.22it/s, bce_dice_loss - 0.1893, iou - 0.9251, f-score - 0.959]
#
# Epoch: 42
# train: 100%|███████████████████| 83/83 [00:50<00:00,  1.66it/s, bce_dice_loss - 0.0436, iou - 0.9807, f-score - 0.9902]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.90it/s, bce_dice_loss - 0.1844, iou - 0.9267, f-score - 0.9598]
# Model saved!
#
# Epoch: 43
# train: 100%|██████████████████| 83/83 [00:50<00:00,  1.64it/s, bce_dice_loss - 0.04303, iou - 0.9809, f-score - 0.9903]
# valid: 100%|█████████████████| 100/100 [00:03<00:00, 28.99it/s, bce_dice_loss - 0.1895, iou - 0.9253, f-score - 0.9592]
#
# Epoch: 44
# train: 100%|██████████████████| 83/83 [00:54<00:00,  1.53it/s, bce_dice_loss - 0.04369, iou - 0.9806, f-score - 0.9902]
# valid: 100%|█████████████████| 100/100 [00:03<00:00, 27.68it/s, bce_dice_loss - 0.1914, iou - 0.9264, f-score - 0.9595]
#
# Epoch: 45
# train: 100%|██████████████████| 83/83 [00:54<00:00,  1.53it/s, bce_dice_loss - 0.04482, iou - 0.9801, f-score - 0.9899]
# valid: 100%|██████████████████| 100/100 [00:03<00:00, 25.38it/s, bce_dice_loss - 0.1916, iou - 0.9253, f-score - 0.959]
#
# Epoch: 46
# train: 100%|██████████████████| 83/83 [00:54<00:00,  1.52it/s, bce_dice_loss - 0.04522, iou - 0.9804, f-score - 0.9901]
# valid: 100%|█████████████████| 100/100 [00:03<00:00, 27.33it/s, bce_dice_loss - 0.1936, iou - 0.9256, f-score - 0.9591]
#
# Epoch: 47
# train: 100%|██████████████████| 83/83 [00:54<00:00,  1.51it/s, bce_dice_loss - 0.04719, iou - 0.9789, f-score - 0.9892]
# valid: 100%|█████████████████| 100/100 [00:03<00:00, 27.18it/s, bce_dice_loss - 0.1958, iou - 0.9248, f-score - 0.9583]
#
# Epoch: 48
# train: 100%|██████████████████| 83/83 [00:55<00:00,  1.51it/s, bce_dice_loss - 0.05235, iou - 0.9776, f-score - 0.9885]
# valid: 100%|█████████████████| 100/100 [00:03<00:00, 27.30it/s, bce_dice_loss - 0.1891, iou - 0.9271, f-score - 0.9599]
# Model saved!
#
# Epoch: 49
# train: 100%|██████████████████| 83/83 [00:55<00:00,  1.50it/s, bce_dice_loss - 0.04478, iou - 0.9803, f-score - 0.9901]
# valid: 100%|█████████████████| 100/100 [00:03<00:00, 27.26it/s, bce_dice_loss - 0.1864, iou - 0.9264, f-score - 0.9597]

# %%
aug = iaa.Sequential([
    iaa.Fliplr(0.5),
])

# %%
train_data = SegmentationData(TRAIN, TRAIN_MSK, augmentation=aug)
val_data = SegmentationData(VAL, VAL_MSK)

train_loader = DataLoader(train_data, batch_size=16, shuffle=True, num_workers=0)
val_loader = DataLoader(val_data, batch_size=1, shuffle=False, num_workers=0)

# %%
model = smp.Unet(BASE_MODEL, MODEL_WEGHTS)
optimizer = optim.Adam([
    {"params": model.encoder.parameters(), "lr" : 1e-6},
    {"params": model.decoder.parameters(), "lr" : 1e-4},
])

# %%
# create epoch runners 
# it is a simple loop of iterating over dataloader`s samples
train_epoch = smp.utils.train.TrainEpoch(
    model, 
    loss=criterion, 
    metrics=metrics, 
    optimizer=optimizer,
    device=DEVICE,
    verbose=True,
)

val_epoch = smp.utils.train.ValidEpoch(
    model, 
    loss=criterion, 
    metrics=metrics, 
    device=DEVICE,
    verbose=True,
)

# %%
max_score = 0

for i in range(0, 50):
    
    print('\nEpoch: {}'.format(i))
    train_logs = train_epoch.run(train_loader)
    valid_logs = val_epoch.run(val_loader)
    
    # do something (save model, change lr, etc.)
    if max_score < valid_logs['iou']:
        max_score = valid_logs['iou']
        torch.save(model, 'models/best_model_unet_resnet18_fliplr.pth')
        augmentations["Flip-lr"] = {"iou": valid_logs["iou"], 
                           "f-score": valid_logs["f-score"] 
                          }
        print('Model saved!')
            
    if i == 25:
        optimizer.param_groups[1]['lr'] = 1e-5
        optimizer.param_groups[0]['lr'] = 1e-7
# Out:
# Epoch: 0
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.33it/s, bce_dice_loss - 0.6247, iou - 0.7498, f-score - 0.8525]
# valid: 100%|██████████████████| 100/100 [00:03<00:00, 29.16it/s, bce_dice_loss - 0.3936, iou - 0.8357, f-score - 0.905]
# Model saved!
#
# Epoch: 1
# train: 100%|███████████████████| 83/83 [01:01<00:00,  1.35it/s, bce_dice_loss - 0.2775, iou - 0.8807, f-score - 0.9363]
# valid: 100%|██████████████████| 100/100 [00:03<00:00, 29.16it/s, bce_dice_loss - 0.2779, iou - 0.876, f-score - 0.9297]
# Model saved!
#
# Epoch: 2
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.34it/s, bce_dice_loss - 0.2179, iou - 0.9058, f-score - 0.9505]
# valid: 100%|██████████████████| 100/100 [00:03<00:00, 26.91it/s, bce_dice_loss - 0.2262, iou - 0.895, f-score - 0.9416]
# Model saved!
#
# Epoch: 3
# train: 100%|███████████████████| 83/83 [01:03<00:00,  1.30it/s, bce_dice_loss - 0.1764, iou - 0.9241, f-score - 0.9605]
# valid: 100%|███████████████████| 100/100 [00:03<00:00, 26.62it/s, bce_dice_loss - 0.267, iou - 0.8733, f-score - 0.927]
#
# Epoch: 4
# train: 100%|█████████████████████| 83/83 [01:03<00:00,  1.31it/s, bce_dice_loss - 0.1619, iou - 0.93, f-score - 0.9637]
# valid: 100%|█████████████████| 100/100 [00:03<00:00, 27.76it/s, bce_dice_loss - 0.2039, iou - 0.9054, f-score - 0.9478]
# Model saved!
#
# Epoch: 5
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.33it/s, bce_dice_loss - 0.1436, iou - 0.9379, f-score - 0.9679]
# valid: 100%|█████████████████| 100/100 [00:03<00:00, 28.83it/s, bce_dice_loss - 0.2021, iou - 0.9064, f-score - 0.9483]
# Model saved!
#
# Epoch: 6
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.32it/s, bce_dice_loss - 0.1347, iou - 0.9414, f-score - 0.9697]
# valid: 100%|█████████████████| 100/100 [00:03<00:00, 27.03it/s, bce_dice_loss - 0.1836, iou - 0.9152, f-score - 0.9535]
# Model saved!
#
# Epoch: 7
# train: 100%|████████████████████| 83/83 [01:02<00:00,  1.32it/s, bce_dice_loss - 0.123, iou - 0.9469, f-score - 0.9727]
# valid: 100%|█████████████████| 100/100 [00:03<00:00, 28.26it/s, bce_dice_loss - 0.1872, iou - 0.9118, f-score - 0.9513]
#
# Epoch: 8
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.34it/s, bce_dice_loss - 0.1138, iou - 0.9507, f-score - 0.9747]
# valid: 100%|█████████████████| 100/100 [00:03<00:00, 28.83it/s, bce_dice_loss - 0.1767, iou - 0.9196, f-score - 0.9561]
# Model saved!
#
# Epoch: 9
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.34it/s, bce_dice_loss - 0.1136, iou - 0.9508, f-score - 0.9747]
# valid: 100%|█████████████████| 100/100 [00:03<00:00, 28.06it/s, bce_dice_loss - 0.1761, iou - 0.9197, f-score - 0.9555]
# Model saved!
#
# Epoch: 10
# train: 100%|███████████████████| 83/83 [00:58<00:00,  1.41it/s, bce_dice_loss - 0.1108, iou - 0.9525, f-score - 0.9756]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.10it/s, bce_dice_loss - 0.1643, iou - 0.9272, f-score - 0.9601]
# Model saved!
#
# Epoch: 11
# train: 100%|████████████████████| 83/83 [00:55<00:00,  1.50it/s, bce_dice_loss - 0.1077, iou - 0.9533, f-score - 0.976]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.19it/s, bce_dice_loss - 0.1739, iou - 0.9246, f-score - 0.9585]
#
# Epoch: 12
# train: 100%|██████████████████| 83/83 [00:55<00:00,  1.50it/s, bce_dice_loss - 0.09201, iou - 0.9603, f-score - 0.9797]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 34.15it/s, bce_dice_loss - 0.171, iou - 0.9265, f-score - 0.9597]
#
# Epoch: 13
# train: 100%|██████████████████| 83/83 [00:55<00:00,  1.50it/s, bce_dice_loss - 0.09011, iou - 0.9607, f-score - 0.9799]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.14it/s, bce_dice_loss - 0.1663, iou - 0.9282, f-score - 0.9608]
# Model saved!
#
# Epoch: 14
# train: 100%|██████████████████| 83/83 [00:55<00:00,  1.51it/s, bce_dice_loss - 0.08882, iou - 0.9616, f-score - 0.9804]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.28it/s, bce_dice_loss - 0.1957, iou - 0.9123, f-score - 0.9512]
#
# Epoch: 15
# train: 100%|██████████████████| 83/83 [00:55<00:00,  1.51it/s, bce_dice_loss - 0.08691, iou - 0.9623, f-score - 0.9808]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 33.59it/s, bce_dice_loss - 0.1697, iou - 0.9283, f-score - 0.9603]
# Model saved!
#
# Epoch: 16
# train: 100%|██████████████████| 83/83 [00:55<00:00,  1.51it/s, bce_dice_loss - 0.07985, iou - 0.9654, f-score - 0.9824]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.16it/s, bce_dice_loss - 0.1606, iou - 0.9295, f-score - 0.9616]
# Model saved!
#
# Epoch: 17
# train: 100%|███████████████████| 83/83 [00:54<00:00,  1.51it/s, bce_dice_loss - 0.07722, iou - 0.9665, f-score - 0.983]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 33.66it/s, bce_dice_loss - 0.1678, iou - 0.9279, f-score - 0.9604]
#
# Epoch: 18
# train: 100%|██████████████████| 83/83 [00:54<00:00,  1.51it/s, bce_dice_loss - 0.07957, iou - 0.9658, f-score - 0.9826]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.46it/s, bce_dice_loss - 0.1757, iou - 0.9247, f-score - 0.9585]
#
# Epoch: 19
# train: 100%|██████████████████| 83/83 [00:54<00:00,  1.51it/s, bce_dice_loss - 0.07317, iou - 0.9684, f-score - 0.9839]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.57it/s, bce_dice_loss - 0.1702, iou - 0.9314, f-score - 0.9628]
# Model saved!
#
# Epoch: 20
# train: 100%|██████████████████| 83/83 [00:54<00:00,  1.51it/s, bce_dice_loss - 0.07432, iou - 0.9681, f-score - 0.9838]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.21it/s, bce_dice_loss - 0.1632, iou - 0.9312, f-score - 0.9625]
#
# Epoch: 21
# train: 100%|██████████████████| 83/83 [00:54<00:00,  1.51it/s, bce_dice_loss - 0.07104, iou - 0.9692, f-score - 0.9843]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 34.26it/s, bce_dice_loss - 0.1643, iou - 0.933, f-score - 0.9636]
# Model saved!
#
# Epoch: 22
# train: 100%|██████████████████| 83/83 [00:55<00:00,  1.51it/s, bce_dice_loss - 0.06587, iou - 0.9713, f-score - 0.9855]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.59it/s, bce_dice_loss - 0.1738, iou - 0.9248, f-score - 0.9588]
#
# Epoch: 23
# train: 100%|██████████████████| 83/83 [00:54<00:00,  1.51it/s, bce_dice_loss - 0.06457, iou - 0.9718, f-score - 0.9857]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.44it/s, bce_dice_loss - 0.1607, iou - 0.9343, f-score - 0.9642]
# Model saved!
#
# Epoch: 24
# train: 100%|███████████████████| 83/83 [00:54<00:00,  1.51it/s, bce_dice_loss - 0.0629, iou - 0.9726, f-score - 0.9861]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.56it/s, bce_dice_loss - 0.1573, iou - 0.9349, f-score - 0.9648]
# Model saved!
#
# Epoch: 25
# train: 100%|██████████████████| 83/83 [00:54<00:00,  1.51it/s, bce_dice_loss - 0.06285, iou - 0.9726, f-score - 0.9861]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 34.50it/s, bce_dice_loss - 0.173, iou - 0.9302, f-score - 0.9619]
#
# Epoch: 26
# train: 100%|██████████████████| 83/83 [00:54<00:00,  1.52it/s, bce_dice_loss - 0.05989, iou - 0.9739, f-score - 0.9868]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 34.92it/s, bce_dice_loss - 0.1649, iou - 0.933, f-score - 0.9634]
#
# Epoch: 27
# train: 100%|██████████████████| 83/83 [00:54<00:00,  1.52it/s, bce_dice_loss - 0.05757, iou - 0.9749, f-score - 0.9873]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 35.26it/s, bce_dice_loss - 0.169, iou - 0.9334, f-score - 0.9636]
#
# Epoch: 28
# train: 100%|██████████████████| 83/83 [00:54<00:00,  1.52it/s, bce_dice_loss - 0.05693, iou - 0.9752, f-score - 0.9874]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.36it/s, bce_dice_loss - 0.1623, iou - 0.9345, f-score - 0.9644]
#
# Epoch: 29
# train: 100%|██████████████████| 83/83 [00:54<00:00,  1.52it/s, bce_dice_loss - 0.05711, iou - 0.9751, f-score - 0.9874]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.18it/s, bce_dice_loss - 0.1643, iou - 0.9339, f-score - 0.9639]
#
# Epoch: 30
# train: 100%|███████████████████| 83/83 [00:54<00:00,  1.52it/s, bce_dice_loss - 0.05893, iou - 0.9745, f-score - 0.987]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.42it/s, bce_dice_loss - 0.1645, iou - 0.9336, f-score - 0.9638]
#
# Epoch: 31
# train: 100%|███████████████████| 83/83 [00:54<00:00,  1.52it/s, bce_dice_loss - 0.0569, iou - 0.9751, f-score - 0.9874]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.38it/s, bce_dice_loss - 0.1643, iou - 0.9332, f-score - 0.9637]
#
# Epoch: 32
# train: 100%|██████████████████| 83/83 [00:54<00:00,  1.52it/s, bce_dice_loss - 0.05834, iou - 0.9749, f-score - 0.9873]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.23it/s, bce_dice_loss - 0.1647, iou - 0.9343, f-score - 0.9643]
#
# Epoch: 33
# train: 100%|███████████████████| 83/83 [00:54<00:00,  1.52it/s, bce_dice_loss - 0.05699, iou - 0.975, f-score - 0.9873]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.42it/s, bce_dice_loss - 0.1669, iou - 0.9332, f-score - 0.9635]
#
# Epoch: 34
# train: 100%|██████████████████| 83/83 [00:54<00:00,  1.52it/s, bce_dice_loss - 0.05883, iou - 0.9743, f-score - 0.9869]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 35.47it/s, bce_dice_loss - 0.1729, iou - 0.932, f-score - 0.9627]
#
# Epoch: 35
# train: 100%|██████████████████| 83/83 [00:54<00:00,  1.52it/s, bce_dice_loss - 0.05534, iou - 0.9759, f-score - 0.9878]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.39it/s, bce_dice_loss - 0.1639, iou - 0.9334, f-score - 0.9638]
#
# Epoch: 36
# train: 100%|██████████████████| 83/83 [00:54<00:00,  1.52it/s, bce_dice_loss - 0.05512, iou - 0.9759, f-score - 0.9878]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.13it/s, bce_dice_loss - 0.1667, iou - 0.9323, f-score - 0.9632]
#
# Epoch: 37
# train: 100%|██████████████████| 83/83 [00:54<00:00,  1.52it/s, bce_dice_loss - 0.05569, iou - 0.9758, f-score - 0.9878]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.24it/s, bce_dice_loss - 0.1659, iou - 0.9327, f-score - 0.9635]
#
# Epoch: 38
# train: 100%|██████████████████| 83/83 [00:54<00:00,  1.52it/s, bce_dice_loss - 0.05333, iou - 0.9767, f-score - 0.9882]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.22it/s, bce_dice_loss - 0.1617, iou - 0.9345, f-score - 0.9645]
#
# Epoch: 39
# train: 100%|██████████████████| 83/83 [00:54<00:00,  1.52it/s, bce_dice_loss - 0.05401, iou - 0.9764, f-score - 0.9881]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.95it/s, bce_dice_loss - 0.1652, iou - 0.9333, f-score - 0.9638]
#
# Epoch: 40
# train: 100%|███████████████████| 83/83 [00:54<00:00,  1.53it/s, bce_dice_loss - 0.05483, iou - 0.9762, f-score - 0.988]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.27it/s, bce_dice_loss - 0.1663, iou - 0.9335, f-score - 0.9639]
#
# Epoch: 41
# train: 100%|██████████████████| 83/83 [00:54<00:00,  1.53it/s, bce_dice_loss - 0.05427, iou - 0.9764, f-score - 0.9881]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.39it/s, bce_dice_loss - 0.1636, iou - 0.9344, f-score - 0.9644]
#
# Epoch: 42
# train: 100%|███████████████████| 83/83 [00:54<00:00,  1.52it/s, bce_dice_loss - 0.05493, iou - 0.9763, f-score - 0.988]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.27it/s, bce_dice_loss - 0.1692, iou - 0.9333, f-score - 0.9638]
#
# Epoch: 43
# train: 100%|██████████████████| 83/83 [00:54<00:00,  1.52it/s, bce_dice_loss - 0.05239, iou - 0.9771, f-score - 0.9884]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.11it/s, bce_dice_loss - 0.1643, iou - 0.9348, f-score - 0.9645]
#
# Epoch: 44
# train: 100%|██████████████████| 83/83 [00:54<00:00,  1.52it/s, bce_dice_loss - 0.05307, iou - 0.9768, f-score - 0.9883]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.17it/s, bce_dice_loss - 0.1627, iou - 0.9345, f-score - 0.9645]
#
# Epoch: 45
# train: 100%|██████████████████| 83/83 [00:54<00:00,  1.52it/s, bce_dice_loss - 0.05322, iou - 0.9767, f-score - 0.9882]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.37it/s, bce_dice_loss - 0.1639, iou - 0.9345, f-score - 0.9644]
#
# Epoch: 46
# train: 100%|██████████████████| 83/83 [00:54<00:00,  1.53it/s, bce_dice_loss - 0.05203, iou - 0.9772, f-score - 0.9884]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 35.22it/s, bce_dice_loss - 0.163, iou - 0.9351, f-score - 0.9649]
# Model saved!
#
# Epoch: 47
# train: 100%|██████████████████| 83/83 [00:54<00:00,  1.53it/s, bce_dice_loss - 0.05136, iou - 0.9775, f-score - 0.9886]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.02it/s, bce_dice_loss - 0.1667, iou - 0.9343, f-score - 0.9644]
#
# Epoch: 48
# train: 100%|██████████████████| 83/83 [00:54<00:00,  1.52it/s, bce_dice_loss - 0.05188, iou - 0.9774, f-score - 0.9886]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.38it/s, bce_dice_loss - 0.1636, iou - 0.9345, f-score - 0.9644]
#
# Epoch: 49
# train: 100%|███████████████████| 83/83 [00:54<00:00,  1.52it/s, bce_dice_loss - 0.0547, iou - 0.9764, f-score - 0.9881]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 35.14it/s, bce_dice_loss - 0.1672, iou - 0.9337, f-score - 0.964]

# %%
aug = iaa.Sequential([
    iaa.SomeOf(
        (0,3),
        [
             iaa.GaussianBlur(sigma=(0, 2)),
             iaa.GammaContrast(per_channel=True, gamma=(0.25,1.75)),
             iaa.LinearContrast(alpha=(0.25,1.75), per_channel=True)
        ]
    ),
])

# %%
train_data = SegmentationData(TRAIN, TRAIN_MSK, augmentation=aug)
val_data = SegmentationData(VAL, VAL_MSK)

train_loader = DataLoader(train_data, batch_size=16, shuffle=True, num_workers=0)
val_loader = DataLoader(val_data, batch_size=1, shuffle=False, num_workers=0)

# %%
model = smp.Unet(BASE_MODEL, MODEL_WEGHTS)
optimizer = optim.Adam([
    {"params": model.encoder.parameters(), "lr" : 1e-6},
    {"params": model.decoder.parameters(), "lr" : 1e-4},
])

# %%
# create epoch runners 
# it is a simple loop of iterating over dataloader`s samples
train_epoch = smp.utils.train.TrainEpoch(
    model, 
    loss=criterion, 
    metrics=metrics, 
    optimizer=optimizer,
    device=DEVICE,
    verbose=True,
)

val_epoch = smp.utils.train.ValidEpoch(
    model, 
    loss=criterion, 
    metrics=metrics, 
    device=DEVICE,
    verbose=True,
)

# %%
max_score = 0

for i in range(0, 50):
    
    print('\nEpoch: {}'.format(i))
    train_logs = train_epoch.run(train_loader)
    valid_logs = val_epoch.run(val_loader)
    
    # do something (save model, change lr, etc.)
    if max_score < valid_logs['iou']:
        max_score = valid_logs['iou']
        torch.save(model, 'models/best_model_unet_resnet18_contrast.pth')
        augmentations["contrast"] = {"iou": valid_logs["iou"], 
                           "f-score": valid_logs["f-score"] 
                          }
        print('Model saved!')
            
    if i == 25:
        optimizer.param_groups[1]['lr'] = 1e-5
        optimizer.param_groups[0]['lr'] = 1e-7
# Out:
# Epoch: 0
# train: 100%|████████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.7048, iou - 0.704, f-score - 0.8166]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.07it/s, bce_dice_loss - 0.3757, iou - 0.8344, f-score - 0.9047]
# Model saved!
#
# Epoch: 1
# train: 100%|███████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.3307, iou - 0.8637, f-score - 0.9267]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 35.28it/s, bce_dice_loss - 0.295, iou - 0.8683, f-score - 0.9248]
# Model saved!
#
# Epoch: 2
# train: 100%|███████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.2584, iou - 0.8918, f-score - 0.9427]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.43it/s, bce_dice_loss - 0.2438, iou - 0.8891, f-score - 0.9375]
# Model saved!
#
# Epoch: 3
# train: 100%|███████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.2331, iou - 0.9005, f-score - 0.9474]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 35.43it/s, bce_dice_loss - 0.2364, iou - 0.8955, f-score - 0.942]
# Model saved!
#
# Epoch: 4
# train: 100%|███████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.2101, iou - 0.9107, f-score - 0.9532]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.39it/s, bce_dice_loss - 0.2087, iou - 0.9041, f-score - 0.9473]
# Model saved!
#
# Epoch: 5
# train: 100%|███████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.1897, iou - 0.9194, f-score - 0.9579]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.97it/s, bce_dice_loss - 0.1933, iou - 0.9125, f-score - 0.9524]
# Model saved!
#
# Epoch: 6
# train: 100%|████████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.183, iou - 0.9219, f-score - 0.9593]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.18it/s, bce_dice_loss - 0.1935, iou - 0.9096, f-score - 0.9501]
#
# Epoch: 7
# train: 100%|███████████████████| 83/83 [00:58<00:00,  1.42it/s, bce_dice_loss - 0.1732, iou - 0.9267, f-score - 0.9619]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.55it/s, bce_dice_loss - 0.2067, iou - 0.9046, f-score - 0.9474]
#
# Epoch: 8
# train: 100%|███████████████████| 83/83 [00:58<00:00,  1.42it/s, bce_dice_loss - 0.1632, iou - 0.9304, f-score - 0.9638]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.89it/s, bce_dice_loss - 0.1774, iou - 0.9191, f-score - 0.9561]
# Model saved!
#
# Epoch: 9
# train: 100%|███████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.1548, iou - 0.9337, f-score - 0.9657]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.22it/s, bce_dice_loss - 0.1701, iou - 0.9215, f-score - 0.9576]
# Model saved!
#
# Epoch: 10
# train: 100%|███████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.1501, iou - 0.9357, f-score - 0.9667]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.28it/s, bce_dice_loss - 0.1688, iou - 0.9209, f-score - 0.9569]
#
# Epoch: 11
# train: 100%|███████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.1442, iou - 0.9376, f-score - 0.9677]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 34.72it/s, bce_dice_loss - 0.1649, iou - 0.924, f-score - 0.9588]
# Model saved!
#
# Epoch: 12
# train: 100%|███████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.1351, iou - 0.9415, f-score - 0.9698]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 35.08it/s, bce_dice_loss - 0.1621, iou - 0.9248, f-score - 0.959]
# Model saved!
#
# Epoch: 13
# train: 100%|████████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.126, iou - 0.9459, f-score - 0.9721]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.49it/s, bce_dice_loss - 0.1613, iou - 0.9269, f-score - 0.9605]
# Model saved!
#
# Epoch: 14
# train: 100%|████████████████████| 83/83 [00:58<00:00,  1.42it/s, bce_dice_loss - 0.1231, iou - 0.947, f-score - 0.9727]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.57it/s, bce_dice_loss - 0.1564, iou - 0.9273, f-score - 0.9607]
# Model saved!
#
# Epoch: 15
# train: 100%|███████████████████| 83/83 [00:58<00:00,  1.42it/s, bce_dice_loss - 0.1217, iou - 0.9472, f-score - 0.9728]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.27it/s, bce_dice_loss - 0.1642, iou - 0.9248, f-score - 0.9593]
#
# Epoch: 16
# train: 100%|███████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.1188, iou - 0.9484, f-score - 0.9735]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.99it/s, bce_dice_loss - 0.1691, iou - 0.9236, f-score - 0.9583]
#
# Epoch: 17
# train: 100%|███████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.1124, iou - 0.9514, f-score - 0.9751]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.60it/s, bce_dice_loss - 0.1571, iou - 0.9293, f-score - 0.9615]
# Model saved!
#
# Epoch: 18
# train: 100%|███████████████████| 83/83 [00:58<00:00,  1.42it/s, bce_dice_loss - 0.1137, iou - 0.9507, f-score - 0.9747]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.18it/s, bce_dice_loss - 0.1538, iou - 0.9316, f-score - 0.9629]
# Model saved!
#
# Epoch: 19
# train: 100%|███████████████████| 83/83 [00:58<00:00,  1.42it/s, bce_dice_loss - 0.1067, iou - 0.9533, f-score - 0.9761]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.57it/s, bce_dice_loss - 0.1509, iou - 0.9314, f-score - 0.9629]
#
# Epoch: 20
# train: 100%|███████████████████| 83/83 [00:58<00:00,  1.42it/s, bce_dice_loss - 0.1046, iou - 0.9543, f-score - 0.9766]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.92it/s, bce_dice_loss - 0.1601, iou - 0.9278, f-score - 0.9607]
#
# Epoch: 21
# train: 100%|████████████████████| 83/83 [00:58<00:00,  1.42it/s, bce_dice_loss - 0.102, iou - 0.9554, f-score - 0.9771]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.07it/s, bce_dice_loss - 0.1579, iou - 0.9286, f-score - 0.9611]
#
# Epoch: 22
# train: 100%|██████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.09919, iou - 0.9571, f-score - 0.9781]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.19it/s, bce_dice_loss - 0.1496, iou - 0.9312, f-score - 0.9629]
#
# Epoch: 23
# train: 100%|██████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.09791, iou - 0.9573, f-score - 0.9782]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.73it/s, bce_dice_loss - 0.1478, iou - 0.9341, f-score - 0.9645]
# Model saved!
#
# Epoch: 24
# train: 100%|██████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.09459, iou - 0.9587, f-score - 0.9789]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.47it/s, bce_dice_loss - 0.1508, iou - 0.9333, f-score - 0.9643]
#
# Epoch: 25
# train: 100%|██████████████████| 83/83 [00:57<00:00,  1.43it/s, bce_dice_loss - 0.09135, iou - 0.9602, f-score - 0.9797]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.62it/s, bce_dice_loss - 0.1467, iou - 0.9354, f-score - 0.9653]
# Model saved!
#
# Epoch: 26
# train: 100%|██████████████████| 83/83 [00:58<00:00,  1.42it/s, bce_dice_loss - 0.08863, iou - 0.9612, f-score - 0.9802]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.37it/s, bce_dice_loss - 0.1453, iou - 0.9355, f-score - 0.9652]
# Model saved!
#
# Epoch: 27
# train: 100%|███████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.08493, iou - 0.963, f-score - 0.9811]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.37it/s, bce_dice_loss - 0.1449, iou - 0.9358, f-score - 0.9653]
# Model saved!
#
# Epoch: 28
# train: 100%|██████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.08184, iou - 0.9644, f-score - 0.9819]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.34it/s, bce_dice_loss - 0.1487, iou - 0.9338, f-score - 0.9642]
#
# Epoch: 29
# train: 100%|███████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.08469, iou - 0.9627, f-score - 0.981]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.24it/s, bce_dice_loss - 0.1458, iou - 0.9353, f-score - 0.9652]
#
# Epoch: 30
# train: 100%|██████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.08325, iou - 0.9637, f-score - 0.9815]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.62it/s, bce_dice_loss - 0.1443, iou - 0.9363, f-score - 0.9656]
# Model saved!
#
# Epoch: 31
# train: 100%|██████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.08372, iou - 0.9634, f-score - 0.9813]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.33it/s, bce_dice_loss - 0.1447, iou - 0.9355, f-score - 0.9652]
#
# Epoch: 32
# train: 100%|██████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.08482, iou - 0.9634, f-score - 0.9813]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.33it/s, bce_dice_loss - 0.1434, iou - 0.9358, f-score - 0.9656]
#
# Epoch: 33
# train: 100%|██████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.08194, iou - 0.9643, f-score - 0.9818]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.54it/s, bce_dice_loss - 0.1447, iou - 0.9357, f-score - 0.9654]
#
# Epoch: 34
# train: 100%|██████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.08137, iou - 0.9645, f-score - 0.9819]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 35.37it/s, bce_dice_loss - 0.143, iou - 0.9362, f-score - 0.9658]
#
# Epoch: 35
# train: 100%|██████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.08288, iou - 0.9638, f-score - 0.9815]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 35.52it/s, bce_dice_loss - 0.1456, iou - 0.9352, f-score - 0.965]
#
# Epoch: 36
# train: 100%|███████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.0838, iou - 0.9633, f-score - 0.9813]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 35.31it/s, bce_dice_loss - 0.142, iou - 0.9361, f-score - 0.9656]
#
# Epoch: 37
# train: 100%|██████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.08194, iou - 0.9642, f-score - 0.9818]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.37it/s, bce_dice_loss - 0.1431, iou - 0.9351, f-score - 0.9651]
#
# Epoch: 38
# train: 100%|██████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.07883, iou - 0.9654, f-score - 0.9824]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.34it/s, bce_dice_loss - 0.1432, iou - 0.9367, f-score - 0.9658]
# Model saved!
#
# Epoch: 39
# train: 100%|██████████████████| 83/83 [00:58<00:00,  1.41it/s, bce_dice_loss - 0.07892, iou - 0.9656, f-score - 0.9825]
# valid: 100%|█████████████████| 100/100 [00:03<00:00, 32.68it/s, bce_dice_loss - 0.1439, iou - 0.9358, f-score - 0.9654]
#
# Epoch: 40
# train: 100%|██████████████████| 83/83 [00:59<00:00,  1.39it/s, bce_dice_loss - 0.07817, iou - 0.9658, f-score - 0.9826]
# valid: 100%|█████████████████| 100/100 [00:03<00:00, 32.96it/s, bce_dice_loss - 0.1451, iou - 0.9365, f-score - 0.9658]
#
# Epoch: 41
# train: 100%|██████████████████| 83/83 [00:58<00:00,  1.41it/s, bce_dice_loss - 0.07933, iou - 0.9653, f-score - 0.9823]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.23it/s, bce_dice_loss - 0.1415, iou - 0.9364, f-score - 0.9658]
#
# Epoch: 42
# train: 100%|███████████████████| 83/83 [00:58<00:00,  1.42it/s, bce_dice_loss - 0.07768, iou - 0.966, f-score - 0.9827]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.63it/s, bce_dice_loss - 0.1476, iou - 0.9365, f-score - 0.9656]
#
# Epoch: 43
# train: 100%|██████████████████| 83/83 [00:58<00:00,  1.41it/s, bce_dice_loss - 0.07726, iou - 0.9662, f-score - 0.9828]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.41it/s, bce_dice_loss - 0.1433, iou - 0.9364, f-score - 0.9657]
#
# Epoch: 44
# train: 100%|██████████████████| 83/83 [00:58<00:00,  1.42it/s, bce_dice_loss - 0.07787, iou - 0.9659, f-score - 0.9826]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.71it/s, bce_dice_loss - 0.1391, iou - 0.9375, f-score - 0.9665]
# Model saved!
#
# Epoch: 45
# train: 100%|██████████████████| 83/83 [00:58<00:00,  1.41it/s, bce_dice_loss - 0.08238, iou - 0.9636, f-score - 0.9814]
# valid: 100%|███████████████████| 100/100 [00:02<00:00, 34.69it/s, bce_dice_loss - 0.14, iou - 0.9373, f-score - 0.9663]
#
# Epoch: 46
# train: 100%|██████████████████| 83/83 [00:58<00:00,  1.41it/s, bce_dice_loss - 0.07868, iou - 0.9657, f-score - 0.9825]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.62it/s, bce_dice_loss - 0.1397, iou - 0.9362, f-score - 0.9658]
#
# Epoch: 47
# train: 100%|███████████████████| 83/83 [00:58<00:00,  1.41it/s, bce_dice_loss - 0.07626, iou - 0.9666, f-score - 0.983]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 34.52it/s, bce_dice_loss - 0.1384, iou - 0.9385, f-score - 0.967]
# Model saved!
#
# Epoch: 48
# train: 100%|██████████████████| 83/83 [00:58<00:00,  1.41it/s, bce_dice_loss - 0.07576, iou - 0.9669, f-score - 0.9832]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 34.29it/s, bce_dice_loss - 0.143, iou - 0.9375, f-score - 0.9663]
#
# Epoch: 49
# train: 100%|██████████████████| 83/83 [00:58<00:00,  1.42it/s, bce_dice_loss - 0.07676, iou - 0.9663, f-score - 0.9828]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.56it/s, bce_dice_loss - 0.1422, iou - 0.9383, f-score - 0.9667]

# %%
aug = iaa.Sequential([
    iaa.Sometimes(
                0.5,
                iaa.OneOf([
                    iaa.ElasticTransformation(alpha=20, sigma=1),
                    iaa.ElasticTransformation(alpha=200, sigma=20)
                ])
        ),
])

# %%
train_data = SegmentationData(TRAIN, TRAIN_MSK, augmentation=aug)
val_data = SegmentationData(VAL, VAL_MSK)

train_loader = DataLoader(train_data, batch_size=16, shuffle=True, num_workers=0)
val_loader = DataLoader(val_data, batch_size=1, shuffle=False, num_workers=0)

# %%
model = smp.Unet(BASE_MODEL, MODEL_WEGHTS)
optimizer = optim.Adam([
    {"params": model.encoder.parameters(), "lr" : 1e-6},
    {"params": model.decoder.parameters(), "lr" : 1e-4},
])

# %%
# create epoch runners 
# it is a simple loop of iterating over dataloader`s samples
train_epoch = smp.utils.train.TrainEpoch(
    model, 
    loss=criterion, 
    metrics=metrics, 
    optimizer=optimizer,
    device=DEVICE,
    verbose=True,
)

val_epoch = smp.utils.train.ValidEpoch(
    model, 
    loss=criterion, 
    metrics=metrics, 
    device=DEVICE,
    verbose=True,
)

# %%
max_score = 0

for i in range(0, 50):
    
    print('\nEpoch: {}'.format(i))
    train_logs = train_epoch.run(train_loader)
    valid_logs = val_epoch.run(val_loader)
    
    # do something (save model, change lr, etc.)
    if max_score < valid_logs['iou']:
        max_score = valid_logs['iou']
        torch.save(model, 'models/best_model_unet_resnet18_elastic.pth')
        augmentations["elastic"] = {"iou": valid_logs["iou"], 
                           "f-score": valid_logs["f-score"] 
                          }
        print('Model saved!')
            
    if i == 25:
        optimizer.param_groups[1]['lr'] = 1e-5
        optimizer.param_groups[0]['lr'] = 1e-7
# Out:
# Epoch: 0
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.33it/s, bce_dice_loss - 0.8702, iou - 0.7119, f-score - 0.8249]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 33.86it/s, bce_dice_loss - 0.4017, iou - 0.8223, f-score - 0.8965]
# Model saved!
#
# Epoch: 1
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.32it/s, bce_dice_loss - 0.4042, iou - 0.8292, f-score - 0.9063]
# valid: 100%|█████████████████| 100/100 [00:03<00:00, 33.32it/s, bce_dice_loss - 0.3068, iou - 0.8611, f-score - 0.9213]
# Model saved!
#
# Epoch: 2
# train: 100%|████████████████████| 83/83 [01:03<00:00,  1.30it/s, bce_dice_loss - 0.342, iou - 0.8527, f-score - 0.9203]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 33.51it/s, bce_dice_loss - 0.2708, iou - 0.8758, f-score - 0.9304]
# Model saved!
#
# Epoch: 3
# train: 100%|███████████████████| 83/83 [01:03<00:00,  1.30it/s, bce_dice_loss - 0.3102, iou - 0.8658, f-score - 0.9279]
# valid: 100%|█████████████████| 100/100 [00:03<00:00, 33.11it/s, bce_dice_loss - 0.2428, iou - 0.8898, f-score - 0.9391]
# Model saved!
#
# Epoch: 4
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.32it/s, bce_dice_loss - 0.2724, iou - 0.8813, f-score - 0.9368]
# valid: 100%|█████████████████| 100/100 [00:03<00:00, 33.26it/s, bce_dice_loss - 0.2248, iou - 0.8961, f-score - 0.9426]
# Model saved!
#
# Epoch: 5
# train: 100%|████████████████████| 83/83 [01:02<00:00,  1.32it/s, bce_dice_loss - 0.2591, iou - 0.887, f-score - 0.9399]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.44it/s, bce_dice_loss - 0.2118, iou - 0.9018, f-score - 0.9457]
# Model saved!
#
# Epoch: 6
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.33it/s, bce_dice_loss - 0.2437, iou - 0.8934, f-score - 0.9435]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.30it/s, bce_dice_loss - 0.2014, iou - 0.9048, f-score - 0.9472]
# Model saved!
#
# Epoch: 7
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.34it/s, bce_dice_loss - 0.2255, iou - 0.9012, f-score - 0.9479]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.16it/s, bce_dice_loss - 0.1993, iou - 0.9081, f-score - 0.9492]
# Model saved!
#
# Epoch: 8
# train: 100%|████████████████████| 83/83 [01:02<00:00,  1.32it/s, bce_dice_loss - 0.222, iou - 0.9032, f-score - 0.9489]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.30it/s, bce_dice_loss - 0.1922, iou - 0.9126, f-score - 0.9519]
# Model saved!
#
# Epoch: 9
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.32it/s, bce_dice_loss - 0.2176, iou - 0.9044, f-score - 0.9496]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.15it/s, bce_dice_loss - 0.1834, iou - 0.9143, f-score - 0.9529]
# Model saved!
#
# Epoch: 10
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.33it/s, bce_dice_loss - 0.2031, iou - 0.9101, f-score - 0.9528]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.22it/s, bce_dice_loss - 0.1736, iou - 0.9182, f-score - 0.9553]
# Model saved!
#
# Epoch: 11
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.32it/s, bce_dice_loss - 0.2021, iou - 0.9107, f-score - 0.9529]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.71it/s, bce_dice_loss - 0.1835, iou - 0.9175, f-score - 0.9548]
#
# Epoch: 12
# train: 100%|███████████████████| 83/83 [01:03<00:00,  1.31it/s, bce_dice_loss - 0.1935, iou - 0.9141, f-score - 0.9549]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.65it/s, bce_dice_loss - 0.1677, iou - 0.9226, f-score - 0.9579]
# Model saved!
#
# Epoch: 13
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.32it/s, bce_dice_loss - 0.1834, iou - 0.9186, f-score - 0.9575]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.22it/s, bce_dice_loss - 0.1656, iou - 0.9237, f-score - 0.9585]
# Model saved!
#
# Epoch: 14
# train: 100%|████████████████████| 83/83 [01:02<00:00,  1.33it/s, bce_dice_loss - 0.1832, iou - 0.9178, f-score - 0.957]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.52it/s, bce_dice_loss - 0.1601, iou - 0.9261, f-score - 0.9599]
# Model saved!
#
# Epoch: 15
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.33it/s, bce_dice_loss - 0.1787, iou - 0.9213, f-score - 0.9589]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 34.36it/s, bce_dice_loss - 0.161, iou - 0.9245, f-score - 0.9589]
#
# Epoch: 16
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.33it/s, bce_dice_loss - 0.1664, iou - 0.9259, f-score - 0.9615]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.60it/s, bce_dice_loss - 0.1654, iou - 0.9262, f-score - 0.9599]
# Model saved!
#
# Epoch: 17
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.33it/s, bce_dice_loss - 0.1659, iou - 0.9256, f-score - 0.9613]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 34.52it/s, bce_dice_loss - 0.1613, iou - 0.9283, f-score - 0.961]
# Model saved!
#
# Epoch: 18
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.33it/s, bce_dice_loss - 0.1575, iou - 0.9303, f-score - 0.9638]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.47it/s, bce_dice_loss - 0.1725, iou - 0.9219, f-score - 0.9574]
#
# Epoch: 19
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.33it/s, bce_dice_loss - 0.1553, iou - 0.9304, f-score - 0.9639]
# valid: 100%|████████████████████| 100/100 [00:02<00:00, 34.46it/s, bce_dice_loss - 0.163, iou - 0.9264, f-score - 0.96]
#
# Epoch: 20
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.32it/s, bce_dice_loss - 0.1525, iou - 0.9316, f-score - 0.9645]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.57it/s, bce_dice_loss - 0.1495, iou - 0.9325, f-score - 0.9636]
# Model saved!
#
# Epoch: 21
# train: 100%|████████████████████| 83/83 [01:02<00:00,  1.32it/s, bce_dice_loss - 0.152, iou - 0.9323, f-score - 0.9649]
# valid: 100%|███████████████████| 100/100 [00:02<00:00, 34.53it/s, bce_dice_loss - 0.161, iou - 0.9282, f-score - 0.961]
#
# Epoch: 22
# train: 100%|████████████████████| 83/83 [01:02<00:00,  1.33it/s, bce_dice_loss - 0.1529, iou - 0.932, f-score - 0.9646]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.56it/s, bce_dice_loss - 0.1485, iou - 0.9342, f-score - 0.9645]
# Model saved!
#
# Epoch: 23
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.32it/s, bce_dice_loss - 0.1427, iou - 0.9365, f-score - 0.9671]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.46it/s, bce_dice_loss - 0.1564, iou - 0.9305, f-score - 0.9622]
#
# Epoch: 24
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.33it/s, bce_dice_loss - 0.1433, iou - 0.9357, f-score - 0.9667]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 35.11it/s, bce_dice_loss - 0.1496, iou - 0.933, f-score - 0.9634]
#
# Epoch: 25
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.33it/s, bce_dice_loss - 0.1318, iou - 0.9404, f-score - 0.9692]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.54it/s, bce_dice_loss - 0.1522, iou - 0.9328, f-score - 0.9636]
#
# Epoch: 26
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.32it/s, bce_dice_loss - 0.1426, iou - 0.9364, f-score - 0.9671]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.97it/s, bce_dice_loss - 0.1478, iou - 0.9333, f-score - 0.9638]
#
# Epoch: 27
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.33it/s, bce_dice_loss - 0.1341, iou - 0.9398, f-score - 0.9689]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 35.29it/s, bce_dice_loss - 0.147, iou - 0.9342, f-score - 0.9642]
#
# Epoch: 28
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.33it/s, bce_dice_loss - 0.1332, iou - 0.9405, f-score - 0.9693]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.78it/s, bce_dice_loss - 0.1462, iou - 0.9342, f-score - 0.9642]
#
# Epoch: 29
# train: 100%|████████████████████| 83/83 [01:02<00:00,  1.33it/s, bce_dice_loss - 0.1255, iou - 0.9438, f-score - 0.971]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.72it/s, bce_dice_loss - 0.1468, iou - 0.9346, f-score - 0.9646]
# Model saved!
#
# Epoch: 30
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.33it/s, bce_dice_loss - 0.1256, iou - 0.9432, f-score - 0.9707]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.90it/s, bce_dice_loss - 0.1479, iou - 0.9349, f-score - 0.9647]
# Model saved!
#
# Epoch: 31
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.33it/s, bce_dice_loss - 0.1274, iou - 0.9431, f-score - 0.9707]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.34it/s, bce_dice_loss - 0.1444, iou - 0.9357, f-score - 0.9652]
# Model saved!
#
# Epoch: 32
# train: 100%|███████████████████| 83/83 [01:01<00:00,  1.34it/s, bce_dice_loss - 0.1281, iou - 0.9423, f-score - 0.9702]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.17it/s, bce_dice_loss - 0.1466, iou - 0.9348, f-score - 0.9646]
#
# Epoch: 33
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.34it/s, bce_dice_loss - 0.1334, iou - 0.9408, f-score - 0.9694]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.21it/s, bce_dice_loss - 0.1465, iou - 0.9358, f-score - 0.9652]
# Model saved!
#
# Epoch: 34
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.33it/s, bce_dice_loss - 0.1307, iou - 0.9409, f-score - 0.9695]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 35.41it/s, bce_dice_loss - 0.1451, iou - 0.9352, f-score - 0.965]
#
# Epoch: 35
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.33it/s, bce_dice_loss - 0.1296, iou - 0.9423, f-score - 0.9702]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 35.08it/s, bce_dice_loss - 0.1459, iou - 0.9355, f-score - 0.965]
#
# Epoch: 36
# train: 100%|█████████████████████| 83/83 [01:02<00:00,  1.34it/s, bce_dice_loss - 0.1292, iou - 0.9418, f-score - 0.97]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.33it/s, bce_dice_loss - 0.1472, iou - 0.9349, f-score - 0.9647]
#
# Epoch: 37
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.32it/s, bce_dice_loss - 0.1241, iou - 0.9444, f-score - 0.9713]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.09it/s, bce_dice_loss - 0.1466, iou - 0.9355, f-score - 0.9651]
#
# Epoch: 38
# train: 100%|█████████████████████| 83/83 [01:02<00:00,  1.33it/s, bce_dice_loss - 0.1294, iou - 0.9419, f-score - 0.97]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.14it/s, bce_dice_loss - 0.1472, iou - 0.9355, f-score - 0.9651]
#
# Epoch: 39
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.32it/s, bce_dice_loss - 0.1267, iou - 0.9432, f-score - 0.9707]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.91it/s, bce_dice_loss - 0.1506, iou - 0.9348, f-score - 0.9645]
#
# Epoch: 40
# train: 100%|████████████████████| 83/83 [01:02<00:00,  1.34it/s, bce_dice_loss - 0.128, iou - 0.9428, f-score - 0.9705]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.16it/s, bce_dice_loss - 0.1485, iou - 0.9348, f-score - 0.9646]
#
# Epoch: 41
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.33it/s, bce_dice_loss - 0.1236, iou - 0.9448, f-score - 0.9716]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 35.05it/s, bce_dice_loss - 0.1478, iou - 0.935, f-score - 0.9647]
#
# Epoch: 42
# train: 100%|████████████████████| 83/83 [01:02<00:00,  1.33it/s, bce_dice_loss - 0.1267, iou - 0.943, f-score - 0.9706]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.27it/s, bce_dice_loss - 0.1498, iou - 0.9347, f-score - 0.9645]
#
# Epoch: 43
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.33it/s, bce_dice_loss - 0.1263, iou - 0.9437, f-score - 0.9709]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 34.96it/s, bce_dice_loss - 0.1473, iou - 0.9353, f-score - 0.965]
#
# Epoch: 44
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.33it/s, bce_dice_loss - 0.1203, iou - 0.9462, f-score - 0.9723]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.64it/s, bce_dice_loss - 0.1514, iou - 0.9342, f-score - 0.9642]
#
# Epoch: 45
# train: 100%|████████████████████| 83/83 [01:02<00:00,  1.33it/s, bce_dice_loss - 0.1252, iou - 0.9438, f-score - 0.971]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.92it/s, bce_dice_loss - 0.1495, iou - 0.9348, f-score - 0.9646]
#
# Epoch: 46
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.34it/s, bce_dice_loss - 0.1222, iou - 0.9454, f-score - 0.9719]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.07it/s, bce_dice_loss - 0.1488, iou - 0.9353, f-score - 0.9649]
#
# Epoch: 47
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.33it/s, bce_dice_loss - 0.1243, iou - 0.9441, f-score - 0.9712]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 35.27it/s, bce_dice_loss - 0.1531, iou - 0.934, f-score - 0.9641]
#
# Epoch: 48
# train: 100%|███████████████████| 83/83 [01:02<00:00,  1.32it/s, bce_dice_loss - 0.1325, iou - 0.9399, f-score - 0.9688]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.58it/s, bce_dice_loss - 0.1561, iou - 0.9332, f-score - 0.9638]
#
# Epoch: 49
# train: 100%|████████████████████| 83/83 [01:02<00:00,  1.32it/s, bce_dice_loss - 0.132, iou - 0.9399, f-score - 0.9689]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.32it/s, bce_dice_loss - 0.1528, iou - 0.9345, f-score - 0.9644]

# %%
aug = iaa.Sequential([
    iaa.Sometimes(0.5, 
            iaa.Affine(
                scale={"x": (0.9, 1.1), "y": (0.8, 1.2)},
                rotate=(-20, 20),
                order=[0, 1]
            )
    )
])

# %%
train_data = SegmentationData(TRAIN, TRAIN_MSK, augmentation=aug)
val_data = SegmentationData(VAL, VAL_MSK)

train_loader = DataLoader(train_data, batch_size=16, shuffle=True, num_workers=0)
val_loader = DataLoader(val_data, batch_size=1, shuffle=False, num_workers=0)

# %%
model = smp.Unet(BASE_MODEL, MODEL_WEGHTS)
optimizer = optim.Adam([
    {"params": model.encoder.parameters(), "lr" : 1e-6},
    {"params": model.decoder.parameters(), "lr" : 1e-4},
])

# %%
# create epoch runners 
# it is a simple loop of iterating over dataloader`s samples
train_epoch = smp.utils.train.TrainEpoch(
    model, 
    loss=criterion, 
    metrics=metrics, 
    optimizer=optimizer,
    device=DEVICE,
    verbose=True,
)

val_epoch = smp.utils.train.ValidEpoch(
    model, 
    loss=criterion, 
    metrics=metrics, 
    device=DEVICE,
    verbose=True,
)

# %%
max_score = 0

for i in range(0, 50):
    
    print('\nEpoch: {}'.format(i))
    train_logs = train_epoch.run(train_loader)
    valid_logs = val_epoch.run(val_loader)
    
    # do something (save model, change lr, etc.)
    if max_score < valid_logs['iou']:
        max_score = valid_logs['iou']
        torch.save(model, 'models/best_model_unet_resnet18_affine.pth')
        augmentations["affine"] = {"iou": valid_logs["iou"], 
                           "f-score": valid_logs["f-score"] 
                          }
        print('Model saved!')
            
    if i == 25:
        optimizer.param_groups[1]['lr'] = 1e-5
        optimizer.param_groups[0]['lr'] = 1e-7
# Out:
# Epoch: 0
# train: 100%|████████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.6815, iou - 0.719, f-score - 0.8293]
# valid: 100%|█████████████████| 100/100 [00:03<00:00, 32.43it/s, bce_dice_loss - 0.3665, iou - 0.8343, f-score - 0.9041]
# Model saved!
#
# Epoch: 1
# train: 100%|███████████████████| 83/83 [00:58<00:00,  1.42it/s, bce_dice_loss - 0.3227, iou - 0.8597, f-score - 0.9244]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 33.94it/s, bce_dice_loss - 0.2675, iou - 0.8781, f-score - 0.932]
# Model saved!
#
# Epoch: 2
# train: 100%|███████████████████| 83/83 [00:58<00:00,  1.42it/s, bce_dice_loss - 0.2477, iou - 0.8919, f-score - 0.9427]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 33.85it/s, bce_dice_loss - 0.2332, iou - 0.8929, f-score - 0.9405]
# Model saved!
#
# Epoch: 3
# train: 100%|███████████████████| 83/83 [00:58<00:00,  1.42it/s, bce_dice_loss - 0.2128, iou - 0.9066, f-score - 0.9509]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.24it/s, bce_dice_loss - 0.2124, iou - 0.9014, f-score - 0.9458]
# Model saved!
#
# Epoch: 4
# train: 100%|███████████████████| 83/83 [00:58<00:00,  1.42it/s, bce_dice_loss - 0.1902, iou - 0.9163, f-score - 0.9562]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 33.86it/s, bce_dice_loss - 0.1961, iou - 0.9075, f-score - 0.9487]
# Model saved!
#
# Epoch: 5
# train: 100%|███████████████████| 83/83 [00:58<00:00,  1.42it/s, bce_dice_loss - 0.1788, iou - 0.9208, f-score - 0.9587]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.18it/s, bce_dice_loss - 0.2013, iou - 0.9055, f-score - 0.9478]
#
# Epoch: 6
# train: 100%|███████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.1664, iou - 0.9268, f-score - 0.9619]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.34it/s, bce_dice_loss - 0.1805, iou - 0.9166, f-score - 0.9546]
# Model saved!
#
# Epoch: 7
# train: 100%|███████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.1529, iou - 0.9326, f-score - 0.9651]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.14it/s, bce_dice_loss - 0.1841, iou - 0.9154, f-score - 0.9535]
#
# Epoch: 8
# train: 100%|███████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.1502, iou - 0.9334, f-score - 0.9655]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.23it/s, bce_dice_loss - 0.1967, iou - 0.9124, f-score - 0.9514]
#
# Epoch: 9
# train: 100%|███████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.1389, iou - 0.9387, f-score - 0.9683]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 34.06it/s, bce_dice_loss - 0.1715, iou - 0.9194, f-score - 0.956]
# Model saved!
#
# Epoch: 10
# train: 100%|███████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.1313, iou - 0.9415, f-score - 0.9699]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 34.10it/s, bce_dice_loss - 0.1676, iou - 0.923, f-score - 0.9582]
# Model saved!
#
# Epoch: 11
# train: 100%|████████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.129, iou - 0.9424, f-score - 0.9702]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.14it/s, bce_dice_loss - 0.1715, iou - 0.9244, f-score - 0.9586]
# Model saved!
#
# Epoch: 12
# train: 100%|████████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.128, iou - 0.9428, f-score - 0.9705]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.24it/s, bce_dice_loss - 0.1656, iou - 0.9249, f-score - 0.9591]
# Model saved!
#
# Epoch: 13
# train: 100%|████████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.1188, iou - 0.9475, f-score - 0.973]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.27it/s, bce_dice_loss - 0.1574, iou - 0.9282, f-score - 0.9614]
# Model saved!
#
# Epoch: 14
# train: 100%|████████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.1178, iou - 0.9475, f-score - 0.973]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.06it/s, bce_dice_loss - 0.1559, iou - 0.9287, f-score - 0.9616]
# Model saved!
#
# Epoch: 15
# train: 100%|███████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.1125, iou - 0.9498, f-score - 0.9742]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.24it/s, bce_dice_loss - 0.1579, iou - 0.9268, f-score - 0.9601]
#
# Epoch: 16
# train: 100%|███████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.1103, iou - 0.9508, f-score - 0.9748]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 34.78it/s, bce_dice_loss - 0.1505, iou - 0.9312, f-score - 0.963]
# Model saved!
#
# Epoch: 17
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.43it/s, bce_dice_loss - 0.1057, iou - 0.9526, f-score - 0.9757]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.66it/s, bce_dice_loss - 0.1548, iou - 0.9317, f-score - 0.9629]
# Model saved!
#
# Epoch: 18
# train: 100%|████████████████████| 83/83 [00:57<00:00,  1.43it/s, bce_dice_loss - 0.1047, iou - 0.9532, f-score - 0.976]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 34.83it/s, bce_dice_loss - 0.152, iou - 0.9308, f-score - 0.9626]
#
# Epoch: 19
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.1024, iou - 0.9547, f-score - 0.9768]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.83it/s, bce_dice_loss - 0.1579, iou - 0.9292, f-score - 0.9618]
#
# Epoch: 20
# train: 100%|██████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.09896, iou - 0.9558, f-score - 0.9774]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 34.53it/s, bce_dice_loss - 0.1479, iou - 0.934, f-score - 0.9644]
# Model saved!
#
# Epoch: 21
# train: 100%|██████████████████| 83/83 [00:57<00:00,  1.43it/s, bce_dice_loss - 0.09876, iou - 0.9562, f-score - 0.9774]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.89it/s, bce_dice_loss - 0.1446, iou - 0.9364, f-score - 0.9655]
# Model saved!
#
# Epoch: 22
# train: 100%|████████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.1006, iou - 0.955, f-score - 0.9769]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.86it/s, bce_dice_loss - 0.1461, iou - 0.9359, f-score - 0.9653]
#
# Epoch: 23
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.09595, iou - 0.9569, f-score - 0.978]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.78it/s, bce_dice_loss - 0.1411, iou - 0.9352, f-score - 0.9648]
#
# Epoch: 24
# train: 100%|██████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.09266, iou - 0.9587, f-score - 0.9789]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.10it/s, bce_dice_loss - 0.1462, iou - 0.9351, f-score - 0.9644]
#
# Epoch: 25
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.09255, iou - 0.9589, f-score - 0.979]
# valid: 100%|███████████████████| 100/100 [00:02<00:00, 34.91it/s, bce_dice_loss - 0.1428, iou - 0.935, f-score - 0.965]
#
# Epoch: 26
# train: 100%|██████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.08559, iou - 0.9614, f-score - 0.9803]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 35.23it/s, bce_dice_loss - 0.143, iou - 0.9361, f-score - 0.9655]
#
# Epoch: 27
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.08293, iou - 0.9627, f-score - 0.981]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.18it/s, bce_dice_loss - 0.1348, iou - 0.9391, f-score - 0.9672]
# Model saved!
#
# Epoch: 28
# train: 100%|██████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.08036, iou - 0.9641, f-score - 0.9817]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.97it/s, bce_dice_loss - 0.1394, iou - 0.9371, f-score - 0.9656]
#
# Epoch: 29
# train: 100%|██████████████████| 83/83 [00:57<00:00,  1.43it/s, bce_dice_loss - 0.08205, iou - 0.9632, f-score - 0.9812]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.08it/s, bce_dice_loss - 0.1371, iou - 0.9377, f-score - 0.9665]
#
# Epoch: 30
# train: 100%|██████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.07926, iou - 0.9644, f-score - 0.9819]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.00it/s, bce_dice_loss - 0.1364, iou - 0.9392, f-score - 0.9672]
# Model saved!
#
# Epoch: 31
# train: 100%|██████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.08251, iou - 0.9631, f-score - 0.9812]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.86it/s, bce_dice_loss - 0.1385, iou - 0.9373, f-score - 0.9662]
#
# Epoch: 32
# train: 100%|██████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.08153, iou - 0.9636, f-score - 0.9815]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.22it/s, bce_dice_loss - 0.1365, iou - 0.9385, f-score - 0.9669]
#
# Epoch: 33
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.0799, iou - 0.9643, f-score - 0.9818]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.82it/s, bce_dice_loss - 0.1379, iou - 0.9377, f-score - 0.9664]
#
# Epoch: 34
# train: 100%|██████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.07699, iou - 0.9653, f-score - 0.9823]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 35.22it/s, bce_dice_loss - 0.1368, iou - 0.9387, f-score - 0.967]
#
# Epoch: 35
# train: 100%|██████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.07919, iou - 0.9645, f-score - 0.9819]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.84it/s, bce_dice_loss - 0.1413, iou - 0.9375, f-score - 0.9662]
#
# Epoch: 36
# train: 100%|██████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.07752, iou - 0.9651, f-score - 0.9822]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.06it/s, bce_dice_loss - 0.1369, iou - 0.9391, f-score - 0.9672]
#
# Epoch: 37
# train: 100%|██████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.08439, iou - 0.9632, f-score - 0.9812]
# valid: 100%|███████████████████| 100/100 [00:02<00:00, 34.85it/s, bce_dice_loss - 0.139, iou - 0.938, f-score - 0.9664]
#
# Epoch: 38
# train: 100%|██████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.07795, iou - 0.9651, f-score - 0.9822]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.01it/s, bce_dice_loss - 0.1336, iou - 0.9394, f-score - 0.9673]
# Model saved!
#
# Epoch: 39
# train: 100%|██████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.07849, iou - 0.9648, f-score - 0.9821]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.94it/s, bce_dice_loss - 0.1366, iou - 0.9394, f-score - 0.9671]
# Model saved!
#
# Epoch: 40
# train: 100%|██████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.07736, iou - 0.9657, f-score - 0.9825]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.79it/s, bce_dice_loss - 0.1393, iou - 0.9381, f-score - 0.9666]
#
# Epoch: 41
# train: 100%|██████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.07744, iou - 0.9652, f-score - 0.9823]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.06it/s, bce_dice_loss - 0.1397, iou - 0.9373, f-score - 0.9662]
#
# Epoch: 42
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.0776, iou - 0.9652, f-score - 0.9823]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.74it/s, bce_dice_loss - 0.1384, iou - 0.9378, f-score - 0.9661]
#
# Epoch: 43
# train: 100%|██████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.07669, iou - 0.9658, f-score - 0.9826]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.89it/s, bce_dice_loss - 0.1409, iou - 0.9377, f-score - 0.9659]
#
# Epoch: 44
# train: 100%|██████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.07689, iou - 0.9652, f-score - 0.9823]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.77it/s, bce_dice_loss - 0.1361, iou - 0.9387, f-score - 0.9669]
#
# Epoch: 45
# train: 100%|██████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.07598, iou - 0.9661, f-score - 0.9827]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 34.55it/s, bce_dice_loss - 0.1357, iou - 0.9393, f-score - 0.967]
#
# Epoch: 46
# train: 100%|████████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.076, iou - 0.9658, f-score - 0.9826]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.08it/s, bce_dice_loss - 0.1392, iou - 0.9376, f-score - 0.9662]
#
# Epoch: 47
# train: 100%|██████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.07586, iou - 0.9659, f-score - 0.9826]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.06it/s, bce_dice_loss - 0.1389, iou - 0.9376, f-score - 0.9659]
#
# Epoch: 48
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.43it/s, bce_dice_loss - 0.0756, iou - 0.9659, f-score - 0.9827]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 35.06it/s, bce_dice_loss - 0.1346, iou - 0.9391, f-score - 0.967]
#
# Epoch: 49
# train: 100%|██████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.07769, iou - 0.9653, f-score - 0.9823]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.77it/s, bce_dice_loss - 0.1371, iou - 0.9388, f-score - 0.9669]

# %%
aug = iaa.Sequential([
    iaa.Sometimes(0.5, 
                  iaa.OneOf([
                      iaa.CoarseSaltAndPepper(p=0.1, size_px=(5,20)),
                      iaa.SaltAndPepper(p=0.01)
                  ])
    )
])

# %%
train_data = SegmentationData(TRAIN, TRAIN_MSK, augmentation=aug)
val_data = SegmentationData(VAL, VAL_MSK)

train_loader = DataLoader(train_data, batch_size=16, shuffle=True, num_workers=0)
val_loader = DataLoader(val_data, batch_size=1, shuffle=False, num_workers=0)

# %%
model = smp.Unet(BASE_MODEL, MODEL_WEGHTS)
optimizer = optim.Adam([
    {"params": model.encoder.parameters(), "lr" : 1e-6},
    {"params": model.decoder.parameters(), "lr" : 1e-4},
])

# %%
# create epoch runners 
# it is a simple loop of iterating over dataloader`s samples
train_epoch = smp.utils.train.TrainEpoch(
    model, 
    loss=criterion, 
    metrics=metrics, 
    optimizer=optimizer,
    device=DEVICE,
    verbose=True,
)

val_epoch = smp.utils.train.ValidEpoch(
    model, 
    loss=criterion, 
    metrics=metrics, 
    device=DEVICE,
    verbose=True,
)

# %%
max_score = 0

for i in range(0, 50):
    
    print('\nEpoch: {}'.format(i))
    train_logs = train_epoch.run(train_loader)
    valid_logs = val_epoch.run(val_loader)
    
    # do something (save model, change lr, etc.)
    if max_score < valid_logs['iou']:
        max_score = valid_logs['iou']
        torch.save(model, 'models/best_model_unet_resnet18_noise.pth')
        augmentations["noise"] = {"iou": valid_logs["iou"], 
                           "f-score": valid_logs["f-score"] 
                          }
        print('Model saved!')
            
    if i == 25:
        optimizer.param_groups[1]['lr'] = 1e-5
        optimizer.param_groups[0]['lr'] = 1e-7
# Out:
# Epoch: 0
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.9717, iou - 0.6334, f-score - 0.7741]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.19it/s, bce_dice_loss - 0.7329, iou - 0.7064, f-score - 0.8155]
# Model saved!
#
# Epoch: 1
# train: 100%|████████████████████| 83/83 [00:57<00:00,  1.45it/s, bce_dice_loss - 0.7487, iou - 0.693, f-score - 0.8181]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.72it/s, bce_dice_loss - 0.6518, iou - 0.7368, f-score - 0.8366]
# Model saved!
#
# Epoch: 2
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.7037, iou - 0.7079, f-score - 0.8285]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 35.42it/s, bce_dice_loss - 0.6027, iou - 0.7468, f-score - 0.844]
# Model saved!
#
# Epoch: 3
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.6814, iou - 0.7165, f-score - 0.8344]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.92it/s, bce_dice_loss - 0.5986, iou - 0.7546, f-score - 0.8484]
# Model saved!
#
# Epoch: 4
# train: 100%|████████████████████| 83/83 [00:57<00:00,  1.45it/s, bce_dice_loss - 0.654, iou - 0.7259, f-score - 0.8406]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.96it/s, bce_dice_loss - 0.5736, iou - 0.7597, f-score - 0.8523]
# Model saved!
#
# Epoch: 5
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.45it/s, bce_dice_loss - 0.6477, iou - 0.7278, f-score - 0.8421]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.95it/s, bce_dice_loss - 0.5751, iou - 0.7384, f-score - 0.8373]
#
# Epoch: 6
# train: 100%|████████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.6276, iou - 0.7356, f-score - 0.847]
# valid: 100%|█████████████████| 100/100 [00:03<00:00, 33.28it/s, bce_dice_loss - 0.5286, iou - 0.7668, f-score - 0.8569]
# Model saved!
#
# Epoch: 7
# train: 100%|███████████████████| 83/83 [00:58<00:00,  1.41it/s, bce_dice_loss - 0.6163, iou - 0.7407, f-score - 0.8506]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.09it/s, bce_dice_loss - 0.5662, iou - 0.7555, f-score - 0.8508]
#
# Epoch: 8
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.6018, iou - 0.7453, f-score - 0.8536]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.01it/s, bce_dice_loss - 0.5015, iou - 0.7773, f-score - 0.8648]
# Model saved!
#
# Epoch: 9
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.6081, iou - 0.7433, f-score - 0.8518]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.35it/s, bce_dice_loss - 0.5207, iou - 0.7736, f-score - 0.8613]
#
# Epoch: 10
# train: 100%|█████████████████████| 83/83 [00:57<00:00,  1.43it/s, bce_dice_loss - 0.581, iou - 0.754, f-score - 0.8592]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.14it/s, bce_dice_loss - 0.5056, iou - 0.7767, f-score - 0.8636]
#
# Epoch: 11
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.5708, iou - 0.7577, f-score - 0.8616]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.42it/s, bce_dice_loss - 0.4942, iou - 0.7836, f-score - 0.8691]
# Model saved!
#
# Epoch: 12
# train: 100%|████████████████████| 83/83 [00:57<00:00,  1.43it/s, bce_dice_loss - 0.5627, iou - 0.7613, f-score - 0.864]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.15it/s, bce_dice_loss - 0.4964, iou - 0.7789, f-score - 0.8645]
#
# Epoch: 13
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.43it/s, bce_dice_loss - 0.5548, iou - 0.7634, f-score - 0.8654]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 33.92it/s, bce_dice_loss - 0.4851, iou - 0.7835, f-score - 0.8667]
#
# Epoch: 14
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.43it/s, bce_dice_loss - 0.5468, iou - 0.7668, f-score - 0.8674]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 34.08it/s, bce_dice_loss - 0.437, iou - 0.8039, f-score - 0.8839]
# Model saved!
#
# Epoch: 15
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.43it/s, bce_dice_loss - 0.5348, iou - 0.7716, f-score - 0.8706]
# valid: 100%|████████████████████| 100/100 [00:02<00:00, 34.33it/s, bce_dice_loss - 0.4498, iou - 0.8, f-score - 0.8792]
#
# Epoch: 16
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.43it/s, bce_dice_loss - 0.5407, iou - 0.7699, f-score - 0.8694]
# valid: 100%|███████████████████| 100/100 [00:02<00:00, 34.37it/s, bce_dice_loss - 0.43, iou - 0.8084, f-score - 0.8858]
# Model saved!
#
# Epoch: 17
# train: 100%|███████████████████| 83/83 [00:58<00:00,  1.43it/s, bce_dice_loss - 0.5319, iou - 0.7721, f-score - 0.8709]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.30it/s, bce_dice_loss - 0.4196, iou - 0.8078, f-score - 0.8857]
#
# Epoch: 18
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.5153, iou - 0.7791, f-score - 0.8754]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.49it/s, bce_dice_loss - 0.4213, iou - 0.8123, f-score - 0.8877]
# Model saved!
#
# Epoch: 19
# train: 100%|████████████████████| 83/83 [00:57<00:00,  1.43it/s, bce_dice_loss - 0.5169, iou - 0.7803, f-score - 0.876]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.55it/s, bce_dice_loss - 0.3939, iou - 0.8234, f-score - 0.8968]
# Model saved!
#
# Epoch: 20
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.43it/s, bce_dice_loss - 0.5146, iou - 0.7805, f-score - 0.8763]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 34.23it/s, bce_dice_loss - 0.4578, iou - 0.782, f-score - 0.8679]
#
# Epoch: 21
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.4872, iou - 0.7908, f-score - 0.8827]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 34.75it/s, bce_dice_loss - 0.3982, iou - 0.8183, f-score - 0.892]
#
# Epoch: 22
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.43it/s, bce_dice_loss - 0.4891, iou - 0.7902, f-score - 0.8824]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.52it/s, bce_dice_loss - 0.3778, iou - 0.8275, f-score - 0.8996]
# Model saved!
#
# Epoch: 23
# train: 100%|████████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.494, iou - 0.7887, f-score - 0.8813]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.44it/s, bce_dice_loss - 0.4413, iou - 0.7878, f-score - 0.8719]
#
# Epoch: 24
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.4816, iou - 0.7942, f-score - 0.8848]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.12it/s, bce_dice_loss - 0.4489, iou - 0.7904, f-score - 0.8741]
#
# Epoch: 25
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.4869, iou - 0.7915, f-score - 0.8831]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.37it/s, bce_dice_loss - 0.3924, iou - 0.8287, f-score - 0.9008]
# Model saved!
#
# Epoch: 26
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.4583, iou - 0.8019, f-score - 0.8896]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.16it/s, bce_dice_loss - 0.3831, iou - 0.8307, f-score - 0.9019]
# Model saved!
#
# Epoch: 27
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.4716, iou - 0.7975, f-score - 0.8869]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.26it/s, bce_dice_loss - 0.4143, iou - 0.8104, f-score - 0.8879]
#
# Epoch: 28
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.4583, iou - 0.8028, f-score - 0.8902]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.04it/s, bce_dice_loss - 0.3608, iou - 0.8346, f-score - 0.9044]
# Model saved!
#
# Epoch: 29
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.4515, iou - 0.8072, f-score - 0.8929]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.27it/s, bce_dice_loss - 0.3691, iou - 0.8312, f-score - 0.9025]
#
# Epoch: 30
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.4681, iou - 0.7999, f-score - 0.8885]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 35.43it/s, bce_dice_loss - 0.371, iou - 0.8306, f-score - 0.9021]
#
# Epoch: 31
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.4609, iou - 0.8029, f-score - 0.8902]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 35.03it/s, bce_dice_loss - 0.3848, iou - 0.827, f-score - 0.8991]
#
# Epoch: 32
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.4579, iou - 0.8041, f-score - 0.8909]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.08it/s, bce_dice_loss - 0.3996, iou - 0.8179, f-score - 0.8937]
#
# Epoch: 33
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.4489, iou - 0.8063, f-score - 0.8924]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.11it/s, bce_dice_loss - 0.3652, iou - 0.8351, f-score - 0.9046]
# Model saved!
#
# Epoch: 34
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.4459, iou - 0.8079, f-score - 0.8933]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.84it/s, bce_dice_loss - 0.3722, iou - 0.8352, f-score - 0.9043]
# Model saved!
#
# Epoch: 35
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.4498, iou - 0.8069, f-score - 0.8927]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 35.00it/s, bce_dice_loss - 0.3674, iou - 0.8347, f-score - 0.904]
#
# Epoch: 36
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.4552, iou - 0.8058, f-score - 0.8919]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 35.11it/s, bce_dice_loss - 0.3814, iou - 0.8306, f-score - 0.902]
#
# Epoch: 37
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.4582, iou - 0.8038, f-score - 0.8907]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.26it/s, bce_dice_loss - 0.3602, iou - 0.8381, f-score - 0.9064]
# Model saved!
#
# Epoch: 38
# train: 100%|████████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.4559, iou - 0.804, f-score - 0.8909]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.27it/s, bce_dice_loss - 0.3592, iou - 0.8368, f-score - 0.9059]
#
# Epoch: 39
# train: 100%|████████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.455, iou - 0.8047, f-score - 0.8914]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.21it/s, bce_dice_loss - 0.3989, iou - 0.8156, f-score - 0.8919]
#
# Epoch: 40
# train: 100%|████████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.4448, iou - 0.8098, f-score - 0.894]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.16it/s, bce_dice_loss - 0.3567, iou - 0.8384, f-score - 0.9073]
# Model saved!
#
# Epoch: 41
# train: 100%|█████████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.439, iou - 0.813, f-score - 0.8965]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.01it/s, bce_dice_loss - 0.3596, iou - 0.8369, f-score - 0.9063]
#
# Epoch: 42
# train: 100%|████████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.4553, iou - 0.8046, f-score - 0.891]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.16it/s, bce_dice_loss - 0.3974, iou - 0.8207, f-score - 0.8958]
#
# Epoch: 43
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.4447, iou - 0.8083, f-score - 0.8935]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.80it/s, bce_dice_loss - 0.3733, iou - 0.8332, f-score - 0.9034]
#
# Epoch: 44
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.4546, iou - 0.8045, f-score - 0.8912]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 34.98it/s, bce_dice_loss - 0.479, iou - 0.7787, f-score - 0.8656]
#
# Epoch: 45
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.4517, iou - 0.8057, f-score - 0.8917]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 35.16it/s, bce_dice_loss - 0.3519, iou - 0.8399, f-score - 0.908]
# Model saved!
#
# Epoch: 46
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.45it/s, bce_dice_loss - 0.4478, iou - 0.8066, f-score - 0.8925]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.91it/s, bce_dice_loss - 0.3716, iou - 0.8308, f-score - 0.9021]
#
# Epoch: 47
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.4427, iou - 0.8111, f-score - 0.8953]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 34.94it/s, bce_dice_loss - 0.3657, iou - 0.835, f-score - 0.9047]
#
# Epoch: 48
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.45it/s, bce_dice_loss - 0.4365, iou - 0.8124, f-score - 0.8961]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.03it/s, bce_dice_loss - 0.3638, iou - 0.8358, f-score - 0.9055]
#
# Epoch: 49
# train: 100%|███████████████████| 83/83 [00:57<00:00,  1.44it/s, bce_dice_loss - 0.4412, iou - 0.8101, f-score - 0.8947]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 35.08it/s, bce_dice_loss - 0.361, iou - 0.8375, f-score - 0.9061]

# %%
aug = iaa.Sequential([
    iaa.Sometimes(0.5, 
            iaa.GaussianBlur(sigma=(0.5, 5))
    )
])

# %%
train_data = SegmentationData(TRAIN, TRAIN_MSK, augmentation=aug)
val_data = SegmentationData(VAL, VAL_MSK)

train_loader = DataLoader(train_data, batch_size=16, shuffle=True, num_workers=0)
val_loader = DataLoader(val_data, batch_size=1, shuffle=False, num_workers=0)

# %%
model = smp.Unet(BASE_MODEL, MODEL_WEGHTS)
optimizer = optim.Adam([
    {"params": model.encoder.parameters(), "lr" : 1e-6},
    {"params": model.decoder.parameters(), "lr" : 1e-4},
])

# %%
# create epoch runners 
# it is a simple loop of iterating over dataloader`s samples
train_epoch = smp.utils.train.TrainEpoch(
    model, 
    loss=criterion, 
    metrics=metrics, 
    optimizer=optimizer,
    device=DEVICE,
    verbose=True,
)

val_epoch = smp.utils.train.ValidEpoch(
    model, 
    loss=criterion, 
    metrics=metrics, 
    device=DEVICE,
    verbose=True,
)

# %%
max_score = 0

for i in range(0, 50):
    
    print('\nEpoch: {}'.format(i))
    train_logs = train_epoch.run(train_loader)
    valid_logs = val_epoch.run(val_loader)
    
    # do something (save model, change lr, etc.)
    if max_score < valid_logs['iou']:
        max_score = valid_logs['iou']
        torch.save(model, 'models/best_model_unet_resnet18_blur.pth')
        augmentations["blur"] = {"iou": valid_logs["iou"], 
                           "f-score": valid_logs["f-score"] 
                          }
        print('Model saved!')
            
    if i == 25:
        optimizer.param_groups[1]['lr'] = 1e-5
        optimizer.param_groups[0]['lr'] = 1e-7
# Out:
# Epoch: 0
# train: 100%|█████████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 1.018, iou - 0.5987, f-score - 0.715]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.97it/s, bce_dice_loss - 0.3929, iou - 0.8286, f-score - 0.9008]
# Model saved!
#
# Epoch: 1
# train: 100%|████████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.3541, iou - 0.857, f-score - 0.9228]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.94it/s, bce_dice_loss - 0.3118, iou - 0.8565, f-score - 0.9173]
# Model saved!
#
# Epoch: 2
# train: 100%|███████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.2774, iou - 0.8837, f-score - 0.9381]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.31it/s, bce_dice_loss - 0.2554, iou - 0.8817, f-score - 0.9334]
# Model saved!
#
# Epoch: 3
# train: 100%|████████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.2416, iou - 0.8996, f-score - 0.947]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.18it/s, bce_dice_loss - 0.2286, iou - 0.8936, f-score - 0.9407]
# Model saved!
#
# Epoch: 4
# train: 100%|███████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.2152, iou - 0.9096, f-score - 0.9525]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 35.07it/s, bce_dice_loss - 0.219, iou - 0.8999, f-score - 0.9444]
# Model saved!
#
# Epoch: 5
# train: 100%|███████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.2025, iou - 0.9157, f-score - 0.9558]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.96it/s, bce_dice_loss - 0.2012, iou - 0.9077, f-score - 0.9491]
# Model saved!
#
# Epoch: 6
# train: 100%|███████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.1884, iou - 0.9222, f-score - 0.9594]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.04it/s, bce_dice_loss - 0.1983, iou - 0.9096, f-score - 0.9503]
# Model saved!
#
# Epoch: 7
# train: 100%|███████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.1701, iou - 0.9299, f-score - 0.9636]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.10it/s, bce_dice_loss - 0.2137, iou - 0.9064, f-score - 0.9483]
#
# Epoch: 8
# train: 100%|███████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.1681, iou - 0.9303, f-score - 0.9638]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.05it/s, bce_dice_loss - 0.1949, iou - 0.9107, f-score - 0.9505]
# Model saved!
#
# Epoch: 9
# train: 100%|███████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.1565, iou - 0.9347, f-score - 0.9661]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.02it/s, bce_dice_loss - 0.1842, iou - 0.9181, f-score - 0.9546]
# Model saved!
#
# Epoch: 10
# train: 100%|███████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.1501, iou - 0.9378, f-score - 0.9678]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 35.16it/s, bce_dice_loss - 0.1824, iou - 0.9166, f-score - 0.954]
#
# Epoch: 11
# train: 100%|███████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.1443, iou - 0.9404, f-score - 0.9692]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 34.73it/s, bce_dice_loss - 0.1866, iou - 0.9152, f-score - 0.953]
#
# Epoch: 12
# train: 100%|████████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.1365, iou - 0.9438, f-score - 0.971]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 35.03it/s, bce_dice_loss - 0.1836, iou - 0.918, f-score - 0.9546]
#
# Epoch: 13
# train: 100%|████████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.1285, iou - 0.947, f-score - 0.9727]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.11it/s, bce_dice_loss - 0.1775, iou - 0.9203, f-score - 0.9563]
# Model saved!
#
# Epoch: 14
# train: 100%|███████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.1306, iou - 0.9464, f-score - 0.9724]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.01it/s, bce_dice_loss - 0.1778, iou - 0.9194, f-score - 0.9554]
#
# Epoch: 15
# train: 100%|███████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.1252, iou - 0.9477, f-score - 0.9731]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.94it/s, bce_dice_loss - 0.1705, iou - 0.9215, f-score - 0.9567]
# Model saved!
#
# Epoch: 16
# train: 100%|███████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.1223, iou - 0.9491, f-score - 0.9738]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.10it/s, bce_dice_loss - 0.1729, iou - 0.9225, f-score - 0.9573]
# Model saved!
#
# Epoch: 17
# train: 100%|███████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.1242, iou - 0.9483, f-score - 0.9734]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 35.11it/s, bce_dice_loss - 0.1743, iou - 0.9203, f-score - 0.956]
#
# Epoch: 18
# train: 100%|███████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.1152, iou - 0.9522, f-score - 0.9755]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 34.91it/s, bce_dice_loss - 0.1784, iou - 0.9199, f-score - 0.956]
#
# Epoch: 19
# train: 100%|████████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.1103, iou - 0.954, f-score - 0.9764]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.80it/s, bce_dice_loss - 0.1677, iou - 0.9254, f-score - 0.9588]
# Model saved!
#
# Epoch: 20
# train: 100%|████████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.1097, iou - 0.954, f-score - 0.9764]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.21it/s, bce_dice_loss - 0.1813, iou - 0.9204, f-score - 0.9563]
#
# Epoch: 21
# train: 100%|███████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.1004, iou - 0.9583, f-score - 0.9787]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.90it/s, bce_dice_loss - 0.1734, iou - 0.9227, f-score - 0.9573]
#
# Epoch: 22
# train: 100%|███████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.1037, iou - 0.9566, f-score - 0.9778]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.13it/s, bce_dice_loss - 0.1755, iou - 0.9223, f-score - 0.9578]
#
# Epoch: 23
# train: 100%|█████████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.0988, iou - 0.959, f-score - 0.979]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.22it/s, bce_dice_loss - 0.1723, iou - 0.9239, f-score - 0.9584]
#
# Epoch: 24
# train: 100%|██████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.09304, iou - 0.9613, f-score - 0.9802]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 35.21it/s, bce_dice_loss - 0.165, iou - 0.9259, f-score - 0.9596]
# Model saved!
#
# Epoch: 25
# train: 100%|██████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.09069, iou - 0.9622, f-score - 0.9807]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.46it/s, bce_dice_loss - 0.1742, iou - 0.9234, f-score - 0.9581]
#
# Epoch: 26
# train: 100%|██████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.08635, iou - 0.9642, f-score - 0.9818]
# valid: 100%|███████████████████| 100/100 [00:02<00:00, 35.41it/s, bce_dice_loss - 0.1638, iou - 0.9267, f-score - 0.96]
# Model saved!
#
# Epoch: 27
# train: 100%|██████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.08809, iou - 0.9637, f-score - 0.9815]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.08it/s, bce_dice_loss - 0.1649, iou - 0.9268, f-score - 0.9602]
# Model saved!
#
# Epoch: 28
# train: 100%|██████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.08328, iou - 0.9657, f-score - 0.9826]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.07it/s, bce_dice_loss - 0.1621, iou - 0.9272, f-score - 0.9603]
# Model saved!
#
# Epoch: 29
# train: 100%|██████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.08491, iou - 0.9648, f-score - 0.9821]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.42it/s, bce_dice_loss - 0.1661, iou - 0.9264, f-score - 0.9598]
#
# Epoch: 30
# train: 100%|████████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.0849, iou - 0.965, f-score - 0.9822]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.23it/s, bce_dice_loss - 0.1683, iou - 0.9272, f-score - 0.9599]
#
# Epoch: 31
# train: 100%|██████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.08319, iou - 0.9655, f-score - 0.9825]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 35.00it/s, bce_dice_loss - 0.1622, iou - 0.9284, f-score - 0.961]
# Model saved!
#
# Epoch: 32
# train: 100%|██████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.08396, iou - 0.9653, f-score - 0.9824]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.08it/s, bce_dice_loss - 0.1622, iou - 0.9283, f-score - 0.9608]
#
# Epoch: 33
# train: 100%|███████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.08226, iou - 0.966, f-score - 0.9827]
# valid: 100%|████████████████████| 100/100 [00:02<00:00, 34.88it/s, bce_dice_loss - 0.166, iou - 0.9273, f-score - 0.96]
#
# Epoch: 34
# train: 100%|████████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.081, iou - 0.9667, f-score - 0.9831]
# valid: 100%|███████████████████| 100/100 [00:02<00:00, 34.95it/s, bce_dice_loss - 0.161, iou - 0.9285, f-score - 0.961]
# Model saved!
#
# Epoch: 35
# train: 100%|██████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.07952, iou - 0.9672, f-score - 0.9833]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.18it/s, bce_dice_loss - 0.1647, iou - 0.9281, f-score - 0.9605]
#
# Epoch: 36
# train: 100%|██████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.08492, iou - 0.9654, f-score - 0.9824]
# valid: 100%|███████████████████| 100/100 [00:02<00:00, 34.73it/s, bce_dice_loss - 0.1673, iou - 0.9273, f-score - 0.96]
#
# Epoch: 37
# train: 100%|██████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.08614, iou - 0.9644, f-score - 0.9818]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.95it/s, bce_dice_loss - 0.1785, iou - 0.9241, f-score - 0.9578]
#
# Epoch: 38
# train: 100%|██████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.08294, iou - 0.9657, f-score - 0.9825]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 35.12it/s, bce_dice_loss - 0.167, iou - 0.9271, f-score - 0.9597]
#
# Epoch: 39
# train: 100%|██████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.08344, iou - 0.9664, f-score - 0.9829]
# valid: 100%|███████████████████| 100/100 [00:02<00:00, 35.18it/s, bce_dice_loss - 0.1651, iou - 0.9272, f-score - 0.96]
#
# Epoch: 40
# train: 100%|██████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.07971, iou - 0.9671, f-score - 0.9833]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.13it/s, bce_dice_loss - 0.1673, iou - 0.9273, f-score - 0.9599]
#
# Epoch: 41
# train: 100%|████████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.0795, iou - 0.967, f-score - 0.9832]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.17it/s, bce_dice_loss - 0.1653, iou - 0.9278, f-score - 0.9604]
#
# Epoch: 42
# train: 100%|██████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.08103, iou - 0.9668, f-score - 0.9831]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 34.96it/s, bce_dice_loss - 0.1645, iou - 0.9281, f-score - 0.9606]
#
# Epoch: 43
# train: 100%|██████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.07866, iou - 0.9674, f-score - 0.9834]
# valid: 100%|██████████████████| 100/100 [00:02<00:00, 34.92it/s, bce_dice_loss - 0.172, iou - 0.9266, f-score - 0.9593]
#
# Epoch: 44
# train: 100%|██████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.07873, iou - 0.9675, f-score - 0.9835]
# valid: 100%|███████████████████| 100/100 [00:02<00:00, 34.92it/s, bce_dice_loss - 0.1657, iou - 0.9266, f-score - 0.96]
#
# Epoch: 45
# train: 100%|██████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.07859, iou - 0.9674, f-score - 0.9834]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.44it/s, bce_dice_loss - 0.1644, iou - 0.9278, f-score - 0.9604]
#
# Epoch: 46
# train: 100%|██████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.07669, iou - 0.9682, f-score - 0.9838]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.16it/s, bce_dice_loss - 0.1674, iou - 0.9273, f-score - 0.9601]
#
# Epoch: 47
# train: 100%|██████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.07808, iou - 0.9678, f-score - 0.9836]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.07it/s, bce_dice_loss - 0.1667, iou - 0.9277, f-score - 0.9604]
#
# Epoch: 48
# train: 100%|██████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.07843, iou - 0.9675, f-score - 0.9835]
# valid: 100%|█████████████████| 100/100 [00:02<00:00, 35.34it/s, bce_dice_loss - 0.1691, iou - 0.9272, f-score - 0.9599]
#
# Epoch: 49
# train: 100%|██████████████████| 83/83 [00:56<00:00,  1.47it/s, bce_dice_loss - 0.08026, iou - 0.9665, f-score - 0.9829]
# valid: 100%|███████████████████| 100/100 [00:02<00:00, 34.89it/s, bce_dice_loss - 0.1689, iou - 0.9277, f-score - 0.96]

# %%
import json

# %%
import pandas as pd

# %%
with open("results/augmentations.json", "w") as f:
    json.dump(augmentations, f)

# %%
pd.read_json("results/augmentations.json").T
# Out:
#            f-score       iou
# Flip-lr   0.964886  0.935092
# affine    0.967146  0.939448
# blur      0.961013  0.928530
# contrast  0.967045  0.938485
# elastic   0.965203  0.935752
# no_aug    0.959862  0.927140
# noise     0.908004  0.839923

# %%
pd.read_json()

# %%
augmentations
# Out:
# {'Flip-lr': {'f-score': 0.9648858624696733, 'iou': 0.9350917828083036},
#  'affine': {'f-score': 0.9671458303928373, 'iou': 0.939448472261429},
#  'blur': {'f-score': 0.9610132664442063, 'iou': 0.9285300475358964},
#  'contrast': {'f-score': 0.9670450282096859, 'iou': 0.9384848111867903},
#  'elastic': {'f-score': 0.9652028703689575, 'iou': 0.9357521748542788},
#  'no_aug': {'f-score': 0.959861744046211, 'iou': 0.9271400225162507},
#  'noise': {'f-score': 0.9080041667819023, 'iou': 0.8399234387278557}}
